# %%
import numpy as np
import os

from tflite_model_maker.config import QuantizationConfig
'''
from tflite_model_maker.config import ExportFormat
from tflite_model_maker import model_spec
from tflite_model_maker import object_detector

import tensorflow as tf
assert tf.__version__.startswith('2')
'''
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [10], in <module>
#       1 import numpy as np
#       2 import os
# ----> 4 from tflite_model_maker.config import QuantizationConfig
#       5 '''
#       6 from tflite_model_maker.config import ExportFormat
#       7 from tflite_model_maker import model_spec
#    (...)
#      11 assert tf.__version__.startswith('2')
#      12 '''
#
# File ~/.local/lib/python3.8/site-packages/tflite_model_maker/__init__.py:44, in <module>
#       1 # Copyright 2021 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # pylint: disable=g-bad-import-order,redefined-builtin
#      15 """Public APIs for TFLite Model Maker, a transfer learning library to train custom TFLite models.
#      16
#      17 You can install the package with
#    (...)
#      41 https://www.tensorflow.org/lite/guide/model_maker.
#      42 """
# ---> 44 from tflite_model_maker import audio_classifier
#      45 from tflite_model_maker import config
#      46 from tflite_model_maker import image_classifier
#
# File ~/.local/lib/python3.8/site-packages/tflite_model_maker/audio_classifier/__init__.py:24, in <module>
#       1 # Copyright 2021 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # pylint: disable=g-bad-import-order,redefined-builtin
#      15 """APIs to train an audio classification model.
#      16
#      17 Tutorial:
#    (...)
#      21 https://github.com/tensorflow/examples/blob/master/tensorflow_examples/lite/model_maker/demo/audio_classification_demo.py
#      22 """
# ---> 24 from tensorflow_examples.lite.model_maker.core.data_util.audio_dataloader import DataLoader
#      25 from tensorflow_examples.lite.model_maker.core.task.audio_classifier import AudioClassifier
#      26 from tensorflow_examples.lite.model_maker.core.task.audio_classifier import create
#
# File ~/.local/lib/python3.8/site-packages/tensorflow_examples/lite/model_maker/core/data_util/audio_dataloader.py:24, in <module>
#      21 import random
#      23 import pandas as pd
# ---> 24 import tensorflow as tf
#      25 from tensorflow_examples.lite.model_maker.core.api.api_util import mm_export
#      26 from tensorflow_examples.lite.model_maker.core.data_util import dataloader
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/__init__.py:473, in <module>
#     471 if hasattr(_current_module, "keras"):
#     472   try:
# --> 473     keras._load()
#     474   except ImportError:
#     475     pass
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/util/lazy_loader.py:41, in LazyLoader._load(self)
#      39 """Load the module and insert it into the parent's globals."""
#      40 # Import the target module and insert it into the parent's namespace
# ---> 41 module = importlib.import_module(self.__name__)
#      42 self._parent_module_globals[self._local_name] = module
#      44 # Emit a warning if one was specified
#
# File /usr/lib/python3.8/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/.local/lib/python3.8/site-packages/keras/__init__.py:25, in <module>
#      22 from keras import distribute
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      27 from keras.engine.input_layer import Input
#      28 from keras.engine.sequential import Sequential
#
# File ~/.local/lib/python3.8/site-packages/keras/models.py:20, in <module>
#      18 import tensorflow.compat.v2 as tf
#      19 from keras import backend
# ---> 20 from keras import metrics as metrics_module
#      21 from keras import optimizer_v1
#      22 from keras.engine import functional
#
# File ~/.local/lib/python3.8/site-packages/keras/metrics/__init__.py:23, in <module>
#      20 from tensorflow.python.util.tf_export import keras_export
#      22 # Base classes
# ---> 23 from keras.metrics.base_metric import Metric
#      24 from keras.metrics.base_metric import Reduce
#      25 from keras.metrics.base_metric import Sum
#
# File ~/.local/lib/python3.8/site-packages/keras/metrics/base_metric.py:25, in <module>
#      22 import warnings
#      24 from keras import backend
# ---> 25 from keras.engine import base_layer
#      26 from keras.engine import base_layer_utils
#      27 from keras.engine import keras_tensor
#
# File ~/.local/lib/python3.8/site-packages/keras/engine/base_layer.py:43, in <module>
#      41 from keras.engine import node as node_module
#      42 from keras.mixed_precision import autocast_variable
# ---> 43 from keras.mixed_precision import loss_scale_optimizer
#      44 from keras.mixed_precision import policy
#      45 from keras.saving.saved_model import layer_serialization
#
# File ~/.local/lib/python3.8/site-packages/keras/mixed_precision/loss_scale_optimizer.py:20, in <module>
#      18 from keras import optimizers
#      19 from keras.mixed_precision import loss_scale as keras_loss_scale_module
# ---> 20 from keras.optimizer_experimental import optimizer as optimizer_experimental
#      21 from keras.optimizer_v2 import optimizer_v2
#      22 from keras.optimizer_v2 import utils as optimizer_utils
#
# File ~/.local/lib/python3.8/site-packages/keras/optimizer_experimental/optimizer.py:649, in <module>
#     642     raise NotImplementedError(
#     643         "Restoring functional Optimizers from SavedModels is not currently "
#     644         "supported. Please file a feature request if this limitation bothers "
#     645         "you.")
#     648 # Register the optimizer for loading from saved_model purpose.
# --> 649 tf.__internal__.saved_model.load.register_revived_type(
#     650     "experimentalOptimizer",
#     651     lambda obj: isinstance(obj, Optimizer),
#     652     versions=[
#     653         tf.__internal__.saved_model.load.VersionedTypeRegistration(
#     654             object_factory=lambda proto: RestoredOptimizer(),
#     655             version=2,
#     656             min_producer_version=1,
#     657             min_consumer_version=1)
#     658     ])
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/saved_model/revived_types.py:133, in register_revived_type(identifier, predicate, versions)
#     130   version_numbers.add(registration.version)
#     132 if identifier in _REVIVED_TYPE_REGISTRY:
# --> 133   raise AssertionError(f"Duplicate registrations for type '{identifier}'")
#     135 _REVIVED_TYPE_REGISTRY[identifier] = (predicate, versions)
#     136 _TYPE_IDENTIFIERS.append(identifier)
#
# AssertionError: Duplicate registrations for type 'experimentalOptimizer'
