# %% [markdown]
# # Localisation et détection d'objet
#
# Dans ce TP, nous allons mettre en pratique certaines des méthodes présentées en cours pour localiser des objets dans une image.
#
# En localisation et détection, on cherche à déterminer la position d'un objet, ainsi que sa classe, sous la forme d'une boîte englobante de largeur $b_w$ et hauteur $b_h$, et dont le centre a pour coordonnées le point $(b_x, b_y)$.
#
# <center> <img src="https://drive.google.com/uc?id=1_jHHv6ZDe-3Xz25jIZ6o177laBEfmMRR" style="width:500;height:300px;"></center>
# <caption><center> Figure 1: Modèle de boîte englobante utilisé pour la localisation </center></caption>
#
# Le problème de localisation considère qu'un seul objet est présent sur l'image, alors que le problème de détection cherche à déterminer l'ensemble des objets présents sur l'image.
#
#
#
# Pour commencer, récupérez les images de la base de données :

# %%
# !git clone https://github.com/axelcarlier/mangeoires_loc.git
# Out:
# Cloning into 'mangeoires_loc'...
# remote: Enumerating objects: 2333, done.
# remote: Counting objects: 100% (2333/2333), done.
# remote: Compressing objects: 100% (2333/2333), done.
# remote: Total 2333 (delta 0), reused 2333 (delta 0), pack-reused 0
# Receiving objects: 100% (2333/2333), 48.39 MiB | 21.51 MiB/s, done.

# %% [markdown]
# La base de données consiste en des photographies prises par une caméra reliée à une Raspberry Pi, cachée dans une mangeoire. Plusieurs mangeoires sont disséminées dans la nature en Occitanie, et l'objectif de [ce projet](https://econect.cnrs.fr/) est la reconnaissance des espèces et le comptage des individus qui viennent se poser devant le caméra, afin de suivre l'évolution des populations d'oiseaux et ainsi monitorer la biodiversité.
#
# La base de données qui vous est fournie regroupe 11 espèces d'animaux, majoritairement des oiseaux, désignés par un code :
#
# 1. Mésange charbonnière (**MESCHA**)
# 2. Verdier d'Europe (**VEREUR**)
# 3. Écureuil roux (**ECUROU**)
# 4. Pie bavarde (**PIEBAV**)
# 5. Sittelle torchepot (**SITTOR**)
# 6. Pinson des arbres (**PINARB**)
# 7. Mésange noire (**MESNOI**)
# 8. Mésange nonnette (**MESNON**)
# 9. Mésange bleue (**MESBLE**)
# 10. Rouge-gorge (**ROUGOR**)
# 11. Accenteur mouchet (**ACCMOU**)
#
#
#
# <center> <img src="https://drive.google.com/uc?id=1Eit86N4D0Ea7ai1rBa0o-GmTwckhP9i0" width=200>
# <img src="https://drive.google.com/uc?id=1lC7WL93UqDT_KV2m21yx99N5dkf98nCY" width=200>
# <img src="https://drive.google.com/uc?id=10tzJORcSrSckDWmBDBtc8FUirxdbRxri" width=200>
# <img src="https://drive.google.com/uc?id=1IHZp_B6bc8bADtAReRHhcyOjDQZAXDBQ" width=200></center>
# <caption><center> Figure 2: Exemples d'images de la base de données </center></caption>

# %% [markdown]
# # Localisation et classification d'objet
#
# Dans cette partie, nous allons nous concentrer sur le problème de la localisation d'un seul objet par classe. La base de données a été épurée pour se concentrer uniquement sur ce cas.

# %%
import PIL
from PIL import Image
import csv
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## Préparation des données
#
# Le code ci-dessous permet de charger les données et les formater pour la classification. Prenez le temps de regarder un peu le format des labels $y$.
# Notez que les images sont rendues carrées lors du chargement.

# %%
# Lecture du CSV contenant les informations relatives à la base de données
dataset = []
with open('mangeoires_loc/bd_mangeoires_equilibre.csv', newline='') as csvfile:
	filereader = csv.reader(csvfile, delimiter=' ', quotechar='|')
	for row in filereader:
		data = row[0].split(',')
		if data[0] != 'Data':
			box = [float(data[5]), float(data[6]), float(data[7]), float(data[8])]
			new_entry = {'type': data[0], 'specie': data[1], 'path': data[2], 'shape': [float(data[3]), float(data[4])], 'box': box}
			dataset.append(new_entry)

# Nombre de classes de la base de données et intitulé des classes
class_labels = list(dict.fromkeys([item['specie'] for item in dataset]))
num_classes = len(class_labels)

# Extraction des données d'apprentissage et de test   
dataset_train = [item for item in dataset if item['type']=='TRAIN']
dataset_test = [item for item in dataset if item['type']=='TEST']

print(class_labels)
# Out:
# ['MESCHA', 'VEREUR', 'ECUROU', 'PIEBAV', 'SITTOR', 'PINARB', 'MESNOI', 'MESNON', 'MESBLE', 'ROUGOR', 'ACCMOU']

# %%
def build_localization_tensors(image_size, dataset, num_classes):
  # Préparation des structures de données pour x et y
  x = np.zeros((len(dataset), image_size, image_size, 3))
  y = np.empty((len(dataset), num_classes + 5)) # 1 + 4 + num_classes : présence / boîte englobante / classes

  # Compteur de parcours du dataset
  i = 0

  for item in dataset:
    # Lecture de l'image
    img = Image.open('mangeoires_loc/' + item['path'])
    # Mise à l'échelle de l'image
    img = img.resize((image_size,image_size), Image.ANTIALIAS)
    # Remplissage de la variable x
    x[i] = np.asarray(img)

    y[i, 0] = 1 # Un objet est toujours présent !

    # Coordonnées de boîte englobante
    img_shape = item['shape']
    box = item['box']
    bx = (box[0] + (box[2] - box[0])/2)/img_shape[0]
    by = (box[1] + (box[3] - box[1])/2)/img_shape[1]
    bw = (box[2] - box[0])/img_shape[0]
    bh = (box[3] - box[1])/img_shape[1]
    y[i, 1] = bx
    y[i, 2] = by
    y[i, 3] = bw
    y[i, 4] = bh

    # Probabilités de classe, sous la forme d'une one-hot vector
    label = class_labels.index(item['specie'])
    classes_probabilities = keras.utils.to_categorical(label, num_classes=num_classes)
    y[i, 5:] = classes_probabilities

    i = i+1

  return x, y

# %% [markdown]
# Séparation des données d'entraînement pour extraire un ensemble de validation, et pré-traitement des données.

# %%
from sklearn.model_selection import train_test_split


# Pour la suite du TP on considèrera des images de taille 64x64x3
# Augmenter cette valeur donnerait de meilleurs résultats mais nécessiterait des calculs plus long.
IMAGE_SIZE = 64

# Lecture des données d'entraînement et de test
x, y = build_localization_tensors(IMAGE_SIZE, dataset_train, num_classes)
x_test, y_test = build_localization_tensors(IMAGE_SIZE, dataset_test, num_classes)

#Extraction d'un ensemble de validation
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.10, random_state=42)

# Pour améliorer l'entraînement, on peut centrer-réduire les coordonnées des bounding boxes...
y_std = np.std(y_train, axis=0)
y_mean = np.mean(y_train, axis=0)
y_train[...,1:5] = (y_train[...,1:5] - y_mean[1:5])/y_std[1:5]
y_val[...,1:5] = (y_val[...,1:5] - y_mean[1:5])/y_std[1:5]
y_test[...,1:5] = (y_test[...,1:5] - y_mean[1:5])/y_std[1:5]

# ... et normaliser les valeurs de couleur
x_train = x_train/255
x_val = x_val/255
x_test = x_test/255

# %% [markdown]
# ## Fonctions utiles

# %% [markdown]
# Une fonction de calcul de l'intersection sur union, qui nous sera utile pour les métriques d'évaluation de nos méthodes :
#
# $$ IoU (R_1, R_2) = \frac{\mathcal{A} (R_1 \cap R_2)}{\mathcal{A} (R_1 \cup R_2)}$$

# %%
### A COMPLETER
def intersection_sur_union(box1, box2):
  """
  Calcul de l'intersection sur union entre deux rectangles box1 et box2

  Arguments:
  box1, box2 -- les coordonnées des deux rectangles, chacun sous la forme [cx, cy, w, h]
                où (cx, cy) désigne les coordonnées du centre du rectangle, 
                w sa largeur et h sa hauteur

  Retourne :
  iou -- la valeur d'intersection sur union entre les deux rectangles 
  """

  x_int_min = max(box1[0]-box1[2]/2, box2[0]-box2[2]/2)
  x_int_max = min(box1[0]+box1[2]/2, box2[0]+box2[2]/2)
  y_int_min = max(box1[1]-box1[3]/2, box2[1]-box2[3]/2)
  y_int_max = min(box1[1]+box1[3]/2, box2[1]+box2[3]/2)

  if (x_int_max < x_int_min) or (y_int_max < y_int_min):
    area_inter = 0
  else: 
    area_inter = (x_int_max - x_int_min) * (y_int_max - y_int_min)
    
  area_union = (box1[2]*box1[3]) + (box2[2]*box2[3]) - area_inter

  return area_inter / area_union

# %%
print(intersection_sur_union([2.5, 2, 1, 4], [2, 3, 4, 2]))
# Out:
# 0.2

# %% [markdown]
# Calcul des différentes métriques :
#
# $$ P = \frac{TP}{TP + FP} $$
#
# $$ R = \frac{TP}{TP + FN} $$
#
# $$ F1 = \frac{2}{\frac{1}{P} + \frac{1}{R}} $$
#
# où $TP$ désigne le nombre de vrais positifs, $FP$ le nombre de faux positifs, $FN$ le nombre de faux négatifs, $P$ la précision, $R$ le rappel et $F1$ le F1-score.

# %%
# On considère souvent qu'une détection est correcte si la classification est valide et que
# l'intersection sur union entre vérité terrain et prédiction est supérieure à 0.5
def global_accuracy(y_true, y_pred, iou_thres=0.5):
  """
  Calcul, pour chaque classe de la précision, du rappel et du F1-score ainsi 
  que du pourcentage global de bonnes détections.

  Arguments:
  y_true -- les labels de la vérité terrain, de dimension (M, 1+4+N) où M désigne
          le nombre d'éléments du dataset et N le nombre de classes (11 dans notre cas)
  y_pred -- les labels prédits par un modèle, de dimension (M, 1+4+N)  
  iou_thres -- seuil d'intersection sur union entre une boîte "vérité-terrain" et 
              une boite prédite au-dessus duquel on considère que la prédiction est correcte          

  Retourne :
  class_res -- liste de longueur N contenant des dictionnaires sous la forme 
            {"Précision": p, "Rappel": r, "F-score": f} résumant les métriques
            précision, rappel et F1-score pour chacune des classes.
  accuracy -- pourcentage global de bonnes détections
  """
  # Initialisation des métriques : nombre de vrais positifs (TP), faux positifs (FP)
  # et faux négatifs (FN) pour chaque classe
  class_metrics = []
  for i in range(num_classes):
    class_metrics.append({'TP': 0, 'FP': 0, 'FN': 0})

  # Nombres de détections correctes et de détections incorrectes
  total_correct_detections = 0
  toal_incorrect_detections = 0
  for i in range(y_true.shape[0]):
    # Labels vérité-terrain et prédits
    groundtruth_label = np.argmax(y_true[i,5:])
    predicted_label = np.argmax(y_pred[i,5:])

    # Coordonnées de boîtes englobantes réelles et prédites
    bx_true = (y_true[i,1]*y_std[1] + y_mean[1])
    by_true = (y_true[i,2]*y_std[2] + y_mean[2])
    bw_true = (y_true[i,3]*y_std[3] + y_mean[3])
    bh_true = (y_true[i,4]*y_std[4] + y_mean[4])  
    bx_pred = (y_pred[i,1]*y_std[1] + y_mean[1])
    by_pred = (y_pred[i,2]*y_std[2] + y_mean[2])
    bw_pred = (y_pred[i,3]*y_std[3] + y_mean[3])
    bh_pred = (y_pred[i,4]*y_std[4] + y_mean[4])  

    # Calcul de l'intersection sur union
    iou = intersection_sur_union([bx_true, by_true, bw_true, bh_true], [bx_pred, by_pred, bw_pred, bh_pred])
    
    # Si la détection est correcte : 
    if groundtruth_label == predicted_label and iou > iou_thres:
      class_metrics[groundtruth_label]['TP'] += 1
      total_correct_detections += 1
    else:
      class_metrics[groundtruth_label]['FN'] += 1
      class_metrics[predicted_label]['FP'] += 1
      toal_incorrect_detections += 1

  class_res = []
  for i in range(num_classes):
    P = class_metrics[i]['TP'] / max(class_metrics[i]['TP'] + class_metrics[i]['FP'], 1)
    R = class_metrics[i]['TP'] / max(class_metrics[i]['TP'] + class_metrics[i]['FN'], 1)
    if P == 0 or R == 0:
      F_score = 0
    else:
      F_score = 2/(1/P + 1/R)

    class_res.append({'Precision': P, 'Rappel': R, 'F-score': F_score})

  accuracy = 100*total_correct_detections/(total_correct_detections + toal_incorrect_detections)
  
  return class_res, accuracy

# %% [markdown]
# La fonction ci-dessous permet de calculer l'intersection sur union  sur des tenseurs (et non des tableaux numpy), elle sera donc utilisable comme métrique pendant l'entraînement.

# %%
def compute_iou(y_true, y_pred):
  ### "Dénormalisation" des coordonnées des boîtes englobantes
  pred_box_xy = y_pred[..., 0:2]* y_std[0:2] + y_mean[0:2]
  true_box_xy = y_true[..., 0:2]* y_std[0:2] + y_mean[0:2]

  ### "Dénormalisation" des largeur et hauteur des boîtes englobantes
  pred_box_wh = y_pred[..., 2:4] * y_std[2:4] + y_mean[2:4]
  true_box_wh = y_true[..., 2:4] * y_std[2:4] + y_mean[2:4]
    
  # Calcul des coordonnées minimales et maximales des boiptes englobantes réelles
  true_wh_half = true_box_wh / 2.
  true_mins    = true_box_xy - true_wh_half
  true_maxes   = true_box_xy + true_wh_half
  
  # Calcul des coordonnées minimales et maximales des boiptes englobantes prédites
  pred_wh_half = pred_box_wh / 2.
  pred_mins    = pred_box_xy - pred_wh_half
  pred_maxes   = pred_box_xy + pred_wh_half       
  
  # Détermination de l'intersection des boîtes englobantes
  intersect_mins  = tf.maximum(pred_mins,  true_mins)
  intersect_maxes = tf.minimum(pred_maxes, true_maxes)
  intersect_wh    = tf.maximum(intersect_maxes - intersect_mins, 0.)
  intersect_areas = intersect_wh[..., 0] * intersect_wh[..., 1]
  
  # Aire des boîtes englobantes prédites et réelles
  true_areas = true_box_wh[..., 0] * true_box_wh[..., 1]
  pred_areas = pred_box_wh[..., 0] * pred_box_wh[..., 1]

  # Aire de l'union des boîtes prédites et réelles
  union_areas = pred_areas + true_areas - intersect_areas

  iou_scores  = tf.truediv(intersect_areas, union_areas)
  return iou_scores

def iou():
  def iou_metrics(y_true, y_pred):
    return compute_iou(y_true, y_pred)
  iou_metrics.__name__= "IoU"
  return iou_metrics

# %% [markdown]
# Visualisation des données et labels

# %%
# Si seuls x et y sont indiqués, on tire au hasard un numéro d'image et on affiche le label y associé  à l'image
# Si un 2e y, nommé y_pred, est indiqué, alors les deux labels sont affichés côte à côte, afin de pouvoir les comparer
# Enfin on peut également indiquer l'id de l'image que l'on souhaite visualiser.
def print_data_localisation(x, y, y_pred=[], id=None, image_size=64):
  if id==None:
    # Tirage aléatoire d'une image dans la base
    num_img = np.random.randint(x.shape[0]-1)
  else:
    num_img = id

  img = x[num_img]
  lab = y[num_img]

  colors = ["blue", "yellow", "red", "orange", "coral", "gold", "ivory", "fuchsia", "purple", "cyan", "navy"] # Différentes couleurs pour les différentes classes
  classes = ['MESCHA', 'VEREUR', 'ECUROU', 'PIEBAV', 'SITTOR', 'PINARB', 'MESNOI', 'MESNON', 'MESBLE', 'ROUGOR', 'ACCMOU']

  if np.any(y_pred):
    plt.subplot(1, 2, 1)

  # Affichage de l'image
  plt.imshow(img)
  # Détermination de la classe
  class_id = np.argmax(lab[5:])

  # Détermination des coordonnées de la boîte englobante dans le repère image
  ax = (lab[1]*y_std[1] + y_mean[1]) * image_size
  ay = (lab[2]*y_std[2] + y_mean[2]) * image_size
  width = (lab[3]*y_std[3] + y_mean[3]) * image_size
  height = (lab[4]*y_std[4] + y_mean[4]) * image_size
  #print("x: {}, y: {}, w: {}, h:{}".format(ax,ay,width, height))
  # Détermination des extrema de la boîte englobante
  p_x = [ax-width/2, ax+width/2]
  p_y = [ay-height/2, ay+height/2]
  # Affichage de la boîte englobante, dans la bonne couleur
  plt.plot([p_x[0], p_x[0]],p_y,color=colors[class_id])
  plt.plot([p_x[1], p_x[1]],p_y,color=colors[class_id])
  plt.plot(p_x,[p_y[0],p_y[0]],color=colors[class_id])
  plt.plot(p_x,[p_y[1],p_y[1]],color=colors[class_id])
  plt.title("Vérité Terrain : Image {} - {}".format(num_img, classes[class_id]))

  if np.any(y_pred):
    plt.subplot(1, 2, 2)
    # Affichage de l'image
    plt.imshow(img)
    lab = y_pred[num_img]
    # Détermination de la classe
    class_id = np.argmax(lab[5:])

    # Détermination des coordonnées de la boîte englobante dans le repère image
    ax = (lab[1]*y_std[1] + y_mean[1]) * image_size
    ay = (lab[2]*y_std[2] + y_mean[2]) * image_size
    width = (lab[3]*y_std[3] + y_mean[3]) * image_size
    height = (lab[4]*y_std[4] + y_mean[4]) * image_size
    #print("x: {}, y: {}, w: {}, h:{}".format(ax,ay,width, height))
    # Détermination des extrema de la boîte englobante
    p_x = [ax-width/2, ax+width/2]
    p_y = [ay-height/2, ay+height/2]
    # Affichage de la boîte englobante, dans la bonne couleur
    plt.plot([p_x[0], p_x[0]],p_y,color=colors[class_id])
    plt.plot([p_x[1], p_x[1]],p_y,color=colors[class_id])
    plt.plot(p_x,[p_y[0],p_y[0]],color=colors[class_id])
    plt.plot(p_x,[p_y[1],p_y[1]],color=colors[class_id])
    plt.title("Prédiction : Image {} - {}".format(num_img, classes[class_id]))

  plt.show()

for i in range(10):#x.shape[0]):
    print_data_localisation(x_train, y_train, image_size=IMAGE_SIZE, id=i)

# %% [markdown]
# Fonction d'affichage des courbes d'apprentissage et de validation

# %%
def plot_training_analysis(history, metric='loss'):    

  loss = history.history[metric]
  val_loss = history.history['val_' + metric]

  epochs = range(len(loss))

  plt.plot(epochs, loss, 'b', linestyle="--",label='Training ' + metric)
  plt.plot(epochs, val_loss, 'g', label='Validation ' + metric)
  plt.title('Training and validation ' + metric)
  plt.legend()

  plt.show()

# %% [markdown]
# ## Travail à faire

# %% [markdown]
# <center> <img src="https://drive.google.com/uc?id=1YzCZe4pgnjJDVGklAaCHZ7HhlPJsadg9" width=500></center>
# <caption><center> Figure 3: Illustration de l'architecture du réseau à construire.  </center></caption>
#
# Complétez les codes qui vous sont fournis pour obtenir un algorithme de localisation.
# Vous pouvez utiliser n'importe quelle base convolutive de votre choix, en revanche vous devrez porter une attention particulière à la couche de sortie.
#
# Vous allez en fait produire 3 sorties différentes : une caractérisant la présence d'un objet, une autre fournissant les coordonnées de la boîte englobante, et enfin une dernière effectuant la classification.

# %%
def create_model_localisation(input_shape=(64, 64, 3)):

  input_layer = Input(shape=input_shape)

  conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(input_layer)
  conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
  pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
  
  conv2 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
  conv2 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
  pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
  
  conv3 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
  conv3 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
  pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
  
  conv4 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
  conv4 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
  drop4 = Dropout(0.5)(conv4)
  pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

  prev_layer = Flatten()(pool4)

  output_p = Dense(1, activation='sigmoid', name='p')(prev_layer)
  output_coord = Dense(4, activation='linear', name='coord')(prev_layer)
  output_class = Dense(11, activation='softmax', name='classes')(prev_layer)
  
  output= [output_p, output_coord, output_class]
  model = Model(input_layer, output)

  return model

# %% [markdown]
# <center> <img src="https://drive.google.com/uc?id=1bnh8zU7Os-w-5TT8hV4xDoThKQc-Ywc2" width=500></center>
# <caption><center> Figure 4: Illustration des fonctions de coût à utiliser pour l'entraînement. </center></caption>
#
# Pour entraîner votre réseau, vous allez donc devoir associer une fonction de coût à chacune des sorties du réseau. La fonction de coût totale sera la somme des trois fonctions de coût précédemment définies, pondérées par des poids définis dans la variable *loss_weights*.
#
# **Prenez le temps de tester différentes valeurs de *loss_weights* en fonction de l'évolution des métriques que vous observerez pendant l'entraînement.**
#
# Vous évaluerez vos résultats de manière qualitative (en affichant les boîtes englobantes prédites et réelles) mais aussi quantitatives grâce aux fonctions définies dans la section précédente. **N'hésitez pas à modifier un peu le paramètre iou_threshold positionné par défaut à 0.5** (une valeur de 0.4 vous permettra d'obtenir de meilleurs résultats !)

# %%
batch_size=16
model = create_model_localisation()
opt = Adam(learning_rate=3e-4)  

loss=['binary_crossentropy', 'mse', 'categorical_crossentropy']
metrics=[ ['accuracy'], [iou()], ['accuracy']]
loss_weights = [1, 1, 1]

model.compile(loss=loss,
              optimizer=opt,
              metrics=metrics,
              loss_weights=loss_weights
              )
history = model.fit(x_train, [y_train[:,0], y_train[:,1:5], y_train[:,5:]],
              epochs=50,
              batch_size=batch_size,            
              validation_data=(x_val, [y_val[:,0], y_val[:,1:5], y_val[:,5:]]))
# Out:
# Epoch 1/50
# 118/118 [==============================] - 16s 38ms/step - loss: 2.8971 - p_loss: 0.0230 - coord_loss: 0.9127 - classes_loss: 1.9614 - p_accuracy: 0.9926 - coord_IoU: 0.3867 - classes_accuracy: 0.3335 - val_loss: 2.2782 - val_p_loss: 0.0048 - val_coord_loss: 0.7119 - val_classes_loss: 1.5614 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.4489 - val_classes_accuracy: 0.4238
# Epoch 2/50
# 118/118 [==============================] - 3s 29ms/step - loss: 1.9889 - p_loss: 9.7935e-04 - coord_loss: 0.6478 - classes_loss: 1.3401 - p_accuracy: 1.0000 - coord_IoU: 0.4419 - classes_accuracy: 0.5276 - val_loss: 1.9855 - val_p_loss: 0.0036 - val_coord_loss: 0.6269 - val_classes_loss: 1.3550 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.4544 - val_classes_accuracy: 0.5524
# Epoch 3/50
# 118/118 [==============================] - 3s 28ms/step - loss: 1.7408 - p_loss: 3.6360e-04 - coord_loss: 0.5611 - classes_loss: 1.1794 - p_accuracy: 1.0000 - coord_IoU: 0.4756 - classes_accuracy: 0.5631 - val_loss: 1.8059 - val_p_loss: 0.0023 - val_coord_loss: 0.5136 - val_classes_loss: 1.2899 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.4750 - val_classes_accuracy: 0.5476
# Epoch 4/50
# 118/118 [==============================] - 3s 29ms/step - loss: 1.6113 - p_loss: 2.0612e-04 - coord_loss: 0.5199 - classes_loss: 1.0912 - p_accuracy: 1.0000 - coord_IoU: 0.4766 - classes_accuracy: 0.6007 - val_loss: 1.7058 - val_p_loss: 0.0014 - val_coord_loss: 0.5402 - val_classes_loss: 1.1642 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.4609 - val_classes_accuracy: 0.5905
# Epoch 5/50
# 118/118 [==============================] - 3s 29ms/step - loss: 1.4935 - p_loss: 1.3419e-04 - coord_loss: 0.4799 - classes_loss: 1.0135 - p_accuracy: 1.0000 - coord_IoU: 0.4929 - classes_accuracy: 0.6341 - val_loss: 1.6041 - val_p_loss: 0.0011 - val_coord_loss: 0.4609 - val_classes_loss: 1.1420 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5136 - val_classes_accuracy: 0.5667
# Epoch 6/50
# 118/118 [==============================] - 3s 29ms/step - loss: 1.4079 - p_loss: 1.1303e-04 - coord_loss: 0.4365 - classes_loss: 0.9713 - p_accuracy: 1.0000 - coord_IoU: 0.5165 - classes_accuracy: 0.6304 - val_loss: 1.5155 - val_p_loss: 5.8016e-04 - val_coord_loss: 0.4483 - val_classes_loss: 1.0667 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5242 - val_classes_accuracy: 0.5714
# Epoch 7/50
# 118/118 [==============================] - 3s 29ms/step - loss: 1.2951 - p_loss: 5.3998e-05 - coord_loss: 0.4080 - classes_loss: 0.8871 - p_accuracy: 1.0000 - coord_IoU: 0.5248 - classes_accuracy: 0.6713 - val_loss: 1.4253 - val_p_loss: 4.2849e-04 - val_coord_loss: 0.4225 - val_classes_loss: 1.0024 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5207 - val_classes_accuracy: 0.6524
# Epoch 8/50
# 118/118 [==============================] - 3s 29ms/step - loss: 1.2292 - p_loss: 5.1036e-05 - coord_loss: 0.3824 - classes_loss: 0.8468 - p_accuracy: 1.0000 - coord_IoU: 0.5310 - classes_accuracy: 0.6760 - val_loss: 1.3797 - val_p_loss: 3.7298e-04 - val_coord_loss: 0.4211 - val_classes_loss: 0.9581 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5138 - val_classes_accuracy: 0.6476
# Epoch 9/50
# 118/118 [==============================] - 3s 29ms/step - loss: 1.1474 - p_loss: 2.8480e-05 - coord_loss: 0.3616 - classes_loss: 0.7858 - p_accuracy: 1.0000 - coord_IoU: 0.5269 - classes_accuracy: 0.7084 - val_loss: 1.3169 - val_p_loss: 3.3082e-04 - val_coord_loss: 0.4105 - val_classes_loss: 0.9060 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5371 - val_classes_accuracy: 0.6571
# Epoch 10/50
# 118/118 [==============================] - 4s 30ms/step - loss: 1.0654 - p_loss: 3.6719e-05 - coord_loss: 0.3416 - classes_loss: 0.7237 - p_accuracy: 1.0000 - coord_IoU: 0.5424 - classes_accuracy: 0.7291 - val_loss: 1.2317 - val_p_loss: 1.6214e-04 - val_coord_loss: 0.3606 - val_classes_loss: 0.8710 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5445 - val_classes_accuracy: 0.6905
# Epoch 11/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.9944 - p_loss: 2.4385e-05 - coord_loss: 0.3288 - classes_loss: 0.6656 - p_accuracy: 1.0000 - coord_IoU: 0.5467 - classes_accuracy: 0.7577 - val_loss: 1.2055 - val_p_loss: 1.1972e-04 - val_coord_loss: 0.3635 - val_classes_loss: 0.8418 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5579 - val_classes_accuracy: 0.7095
# Epoch 12/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.9273 - p_loss: 2.2750e-05 - coord_loss: 0.3140 - classes_loss: 0.6132 - p_accuracy: 1.0000 - coord_IoU: 0.5538 - classes_accuracy: 0.7715 - val_loss: 1.1868 - val_p_loss: 7.2800e-05 - val_coord_loss: 0.3793 - val_classes_loss: 0.8075 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5493 - val_classes_accuracy: 0.7286
# Epoch 13/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.8370 - p_loss: 1.1582e-05 - coord_loss: 0.3001 - classes_loss: 0.5370 - p_accuracy: 1.0000 - coord_IoU: 0.5596 - classes_accuracy: 0.8155 - val_loss: 1.1800 - val_p_loss: 1.4120e-04 - val_coord_loss: 0.3594 - val_classes_loss: 0.8204 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5638 - val_classes_accuracy: 0.6810
# Epoch 14/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.8166 - p_loss: 1.2075e-05 - coord_loss: 0.2918 - classes_loss: 0.5248 - p_accuracy: 1.0000 - coord_IoU: 0.5608 - classes_accuracy: 0.8128 - val_loss: 1.1746 - val_p_loss: 1.8928e-04 - val_coord_loss: 0.3876 - val_classes_loss: 0.7868 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5536 - val_classes_accuracy: 0.7286
# Epoch 15/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.7272 - p_loss: 6.5629e-06 - coord_loss: 0.2633 - classes_loss: 0.4639 - p_accuracy: 1.0000 - coord_IoU: 0.5671 - classes_accuracy: 0.8457 - val_loss: 1.0737 - val_p_loss: 8.7514e-05 - val_coord_loss: 0.3193 - val_classes_loss: 0.7543 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5799 - val_classes_accuracy: 0.7238
# Epoch 16/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.6650 - p_loss: 6.1698e-06 - coord_loss: 0.2575 - classes_loss: 0.4075 - p_accuracy: 1.0000 - coord_IoU: 0.5707 - classes_accuracy: 0.8627 - val_loss: 1.1058 - val_p_loss: 7.8968e-05 - val_coord_loss: 0.3432 - val_classes_loss: 0.7625 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5670 - val_classes_accuracy: 0.7143
# Epoch 17/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.5931 - p_loss: 5.0676e-06 - coord_loss: 0.2395 - classes_loss: 0.3536 - p_accuracy: 1.0000 - coord_IoU: 0.5817 - classes_accuracy: 0.8818 - val_loss: 1.0460 - val_p_loss: 7.3809e-05 - val_coord_loss: 0.3299 - val_classes_loss: 0.7160 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5785 - val_classes_accuracy: 0.7524
# Epoch 18/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.5775 - p_loss: 6.0578e-06 - coord_loss: 0.2419 - classes_loss: 0.3356 - p_accuracy: 1.0000 - coord_IoU: 0.5794 - classes_accuracy: 0.8881 - val_loss: 1.0838 - val_p_loss: 8.2726e-05 - val_coord_loss: 0.3632 - val_classes_loss: 0.7206 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5511 - val_classes_accuracy: 0.7238
# Epoch 19/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.5015 - p_loss: 2.7437e-06 - coord_loss: 0.2269 - classes_loss: 0.2746 - p_accuracy: 1.0000 - coord_IoU: 0.5881 - classes_accuracy: 0.9157 - val_loss: 1.0063 - val_p_loss: 2.6583e-05 - val_coord_loss: 0.3342 - val_classes_loss: 0.6721 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5631 - val_classes_accuracy: 0.7667
# Epoch 20/50
# 118/118 [==============================] - 4s 34ms/step - loss: 0.4524 - p_loss: 3.4031e-06 - coord_loss: 0.2045 - classes_loss: 0.2479 - p_accuracy: 1.0000 - coord_IoU: 0.6018 - classes_accuracy: 0.9215 - val_loss: 1.0183 - val_p_loss: 3.2951e-05 - val_coord_loss: 0.3200 - val_classes_loss: 0.6983 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5718 - val_classes_accuracy: 0.7524
# Epoch 21/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.4204 - p_loss: 4.4522e-06 - coord_loss: 0.2080 - classes_loss: 0.2124 - p_accuracy: 1.0000 - coord_IoU: 0.5937 - classes_accuracy: 0.9316 - val_loss: 0.9702 - val_p_loss: 2.5633e-05 - val_coord_loss: 0.3252 - val_classes_loss: 0.6450 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5737 - val_classes_accuracy: 0.7619
# Epoch 22/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.3873 - p_loss: 3.0460e-06 - coord_loss: 0.1980 - classes_loss: 0.1893 - p_accuracy: 1.0000 - coord_IoU: 0.6118 - classes_accuracy: 0.9470 - val_loss: 0.9523 - val_p_loss: 2.7920e-05 - val_coord_loss: 0.3039 - val_classes_loss: 0.6483 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5927 - val_classes_accuracy: 0.7857
# Epoch 23/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.3286 - p_loss: 2.7477e-06 - coord_loss: 0.1855 - classes_loss: 0.1431 - p_accuracy: 1.0000 - coord_IoU: 0.6163 - classes_accuracy: 0.9650 - val_loss: 0.9778 - val_p_loss: 2.0350e-05 - val_coord_loss: 0.3267 - val_classes_loss: 0.6511 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5805 - val_classes_accuracy: 0.7905
# Epoch 24/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.2966 - p_loss: 1.5787e-06 - coord_loss: 0.1733 - classes_loss: 0.1232 - p_accuracy: 1.0000 - coord_IoU: 0.6215 - classes_accuracy: 0.9708 - val_loss: 1.0702 - val_p_loss: 1.3946e-05 - val_coord_loss: 0.3396 - val_classes_loss: 0.7306 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5734 - val_classes_accuracy: 0.7286
# Epoch 25/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.2854 - p_loss: 1.7415e-06 - coord_loss: 0.1743 - classes_loss: 0.1111 - p_accuracy: 1.0000 - coord_IoU: 0.6172 - classes_accuracy: 0.9740 - val_loss: 0.9433 - val_p_loss: 9.5289e-06 - val_coord_loss: 0.3047 - val_classes_loss: 0.6386 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5908 - val_classes_accuracy: 0.7905
# Epoch 26/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.2367 - p_loss: 1.6090e-06 - coord_loss: 0.1566 - classes_loss: 0.0801 - p_accuracy: 1.0000 - coord_IoU: 0.6355 - classes_accuracy: 0.9857 - val_loss: 0.9206 - val_p_loss: 1.1841e-05 - val_coord_loss: 0.3083 - val_classes_loss: 0.6122 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5824 - val_classes_accuracy: 0.7619
# Epoch 27/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.2209 - p_loss: 1.4738e-06 - coord_loss: 0.1480 - classes_loss: 0.0729 - p_accuracy: 1.0000 - coord_IoU: 0.6392 - classes_accuracy: 0.9852 - val_loss: 0.8910 - val_p_loss: 1.9271e-05 - val_coord_loss: 0.2873 - val_classes_loss: 0.6036 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6103 - val_classes_accuracy: 0.8000
# Epoch 28/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.1927 - p_loss: 2.0043e-06 - coord_loss: 0.1382 - classes_loss: 0.0545 - p_accuracy: 1.0000 - coord_IoU: 0.6524 - classes_accuracy: 0.9926 - val_loss: 0.9556 - val_p_loss: 1.4558e-05 - val_coord_loss: 0.2980 - val_classes_loss: 0.6576 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5993 - val_classes_accuracy: 0.7524
# Epoch 29/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.1667 - p_loss: 1.6653e-06 - coord_loss: 0.1282 - classes_loss: 0.0385 - p_accuracy: 1.0000 - coord_IoU: 0.6576 - classes_accuracy: 0.9963 - val_loss: 0.9817 - val_p_loss: 6.9137e-06 - val_coord_loss: 0.2781 - val_classes_loss: 0.7036 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5978 - val_classes_accuracy: 0.7476
# Epoch 30/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.1609 - p_loss: 1.7697e-06 - coord_loss: 0.1229 - classes_loss: 0.0380 - p_accuracy: 1.0000 - coord_IoU: 0.6566 - classes_accuracy: 0.9963 - val_loss: 0.9148 - val_p_loss: 8.8586e-06 - val_coord_loss: 0.2850 - val_classes_loss: 0.6298 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5912 - val_classes_accuracy: 0.7857
# Epoch 31/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.1406 - p_loss: 1.5543e-06 - coord_loss: 0.1131 - classes_loss: 0.0274 - p_accuracy: 1.0000 - coord_IoU: 0.6661 - classes_accuracy: 0.9973 - val_loss: 0.9479 - val_p_loss: 1.7908e-05 - val_coord_loss: 0.3023 - val_classes_loss: 0.6456 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5818 - val_classes_accuracy: 0.7952
# Epoch 32/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.1349 - p_loss: 1.4786e-06 - coord_loss: 0.1056 - classes_loss: 0.0293 - p_accuracy: 1.0000 - coord_IoU: 0.6793 - classes_accuracy: 0.9979 - val_loss: 0.9415 - val_p_loss: 1.5754e-05 - val_coord_loss: 0.3025 - val_classes_loss: 0.6390 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5977 - val_classes_accuracy: 0.7952
# Epoch 33/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.1208 - p_loss: 1.5040e-06 - coord_loss: 0.1007 - classes_loss: 0.0200 - p_accuracy: 1.0000 - coord_IoU: 0.6885 - classes_accuracy: 1.0000 - val_loss: 0.9455 - val_p_loss: 5.6833e-06 - val_coord_loss: 0.2815 - val_classes_loss: 0.6640 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5952 - val_classes_accuracy: 0.7952
# Epoch 34/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.1128 - p_loss: 2.1561e-06 - coord_loss: 0.0967 - classes_loss: 0.0161 - p_accuracy: 1.0000 - coord_IoU: 0.6959 - classes_accuracy: 1.0000 - val_loss: 0.8963 - val_p_loss: 2.5081e-05 - val_coord_loss: 0.2911 - val_classes_loss: 0.6052 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5971 - val_classes_accuracy: 0.7952
# Epoch 35/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.1095 - p_loss: 1.5511e-06 - coord_loss: 0.0934 - classes_loss: 0.0161 - p_accuracy: 1.0000 - coord_IoU: 0.6933 - classes_accuracy: 0.9989 - val_loss: 0.9170 - val_p_loss: 1.6837e-05 - val_coord_loss: 0.2847 - val_classes_loss: 0.6323 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6097 - val_classes_accuracy: 0.7952
# Epoch 36/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.1326 - p_loss: 1.5018e-06 - coord_loss: 0.1002 - classes_loss: 0.0324 - p_accuracy: 1.0000 - coord_IoU: 0.6865 - classes_accuracy: 0.9947 - val_loss: 0.9402 - val_p_loss: 1.2586e-05 - val_coord_loss: 0.2756 - val_classes_loss: 0.6646 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6139 - val_classes_accuracy: 0.7810
# Epoch 37/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.1105 - p_loss: 1.4145e-06 - coord_loss: 0.0907 - classes_loss: 0.0198 - p_accuracy: 1.0000 - coord_IoU: 0.6966 - classes_accuracy: 0.9979 - val_loss: 0.9414 - val_p_loss: 5.5046e-06 - val_coord_loss: 0.2806 - val_classes_loss: 0.6608 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6051 - val_classes_accuracy: 0.7905
# Epoch 38/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0954 - p_loss: 1.2728e-06 - coord_loss: 0.0838 - classes_loss: 0.0116 - p_accuracy: 1.0000 - coord_IoU: 0.7006 - classes_accuracy: 1.0000 - val_loss: 0.9946 - val_p_loss: 4.5149e-06 - val_coord_loss: 0.2683 - val_classes_loss: 0.7262 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6136 - val_classes_accuracy: 0.7714
# Epoch 39/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0898 - p_loss: 1.4458e-06 - coord_loss: 0.0785 - classes_loss: 0.0114 - p_accuracy: 1.0000 - coord_IoU: 0.7140 - classes_accuracy: 1.0000 - val_loss: 0.9472 - val_p_loss: 1.0344e-05 - val_coord_loss: 0.2695 - val_classes_loss: 0.6776 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6128 - val_classes_accuracy: 0.7857
# Epoch 40/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0865 - p_loss: 1.5099e-06 - coord_loss: 0.0759 - classes_loss: 0.0106 - p_accuracy: 1.0000 - coord_IoU: 0.7149 - classes_accuracy: 1.0000 - val_loss: 0.9508 - val_p_loss: 1.1773e-05 - val_coord_loss: 0.2707 - val_classes_loss: 0.6801 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6145 - val_classes_accuracy: 0.7714
# Epoch 41/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0877 - p_loss: 1.7014e-06 - coord_loss: 0.0726 - classes_loss: 0.0152 - p_accuracy: 1.0000 - coord_IoU: 0.7172 - classes_accuracy: 0.9979 - val_loss: 1.0084 - val_p_loss: 7.7364e-06 - val_coord_loss: 0.2684 - val_classes_loss: 0.7400 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6215 - val_classes_accuracy: 0.7476
# Epoch 42/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0850 - p_loss: 1.1588e-06 - coord_loss: 0.0735 - classes_loss: 0.0115 - p_accuracy: 1.0000 - coord_IoU: 0.7239 - classes_accuracy: 1.0000 - val_loss: 0.9621 - val_p_loss: 1.9573e-05 - val_coord_loss: 0.2907 - val_classes_loss: 0.6714 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6099 - val_classes_accuracy: 0.7714
# Epoch 43/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0790 - p_loss: 9.0130e-07 - coord_loss: 0.0697 - classes_loss: 0.0093 - p_accuracy: 1.0000 - coord_IoU: 0.7310 - classes_accuracy: 1.0000 - val_loss: 0.9415 - val_p_loss: 8.5613e-06 - val_coord_loss: 0.2788 - val_classes_loss: 0.6626 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6111 - val_classes_accuracy: 0.8143
# Epoch 44/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0715 - p_loss: 1.2220e-06 - coord_loss: 0.0641 - classes_loss: 0.0074 - p_accuracy: 1.0000 - coord_IoU: 0.7354 - classes_accuracy: 1.0000 - val_loss: 0.9272 - val_p_loss: 9.5619e-06 - val_coord_loss: 0.2563 - val_classes_loss: 0.6709 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6271 - val_classes_accuracy: 0.7857
# Epoch 45/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0698 - p_loss: 1.5374e-06 - coord_loss: 0.0626 - classes_loss: 0.0072 - p_accuracy: 1.0000 - coord_IoU: 0.7389 - classes_accuracy: 1.0000 - val_loss: 0.9177 - val_p_loss: 6.1762e-06 - val_coord_loss: 0.2662 - val_classes_loss: 0.6515 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6302 - val_classes_accuracy: 0.7905
# Epoch 46/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0683 - p_loss: 1.1738e-06 - coord_loss: 0.0618 - classes_loss: 0.0065 - p_accuracy: 1.0000 - coord_IoU: 0.7376 - classes_accuracy: 1.0000 - val_loss: 0.9389 - val_p_loss: 4.6074e-05 - val_coord_loss: 0.2971 - val_classes_loss: 0.6418 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5987 - val_classes_accuracy: 0.7857
# Epoch 47/50
# 118/118 [==============================] - 3s 30ms/step - loss: 0.0679 - p_loss: 1.5200e-06 - coord_loss: 0.0604 - classes_loss: 0.0076 - p_accuracy: 1.0000 - coord_IoU: 0.7446 - classes_accuracy: 1.0000 - val_loss: 0.9674 - val_p_loss: 4.5627e-06 - val_coord_loss: 0.2667 - val_classes_loss: 0.7007 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6302 - val_classes_accuracy: 0.7714
# Epoch 48/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0694 - p_loss: 9.1784e-07 - coord_loss: 0.0609 - classes_loss: 0.0085 - p_accuracy: 1.0000 - coord_IoU: 0.7430 - classes_accuracy: 0.9995 - val_loss: 0.9789 - val_p_loss: 5.0809e-06 - val_coord_loss: 0.2754 - val_classes_loss: 0.7034 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6067 - val_classes_accuracy: 0.7762
# Epoch 49/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.2259 - p_loss: 7.3869e-07 - coord_loss: 0.1195 - classes_loss: 0.1064 - p_accuracy: 1.0000 - coord_IoU: 0.6647 - classes_accuracy: 0.9671 - val_loss: 0.9993 - val_p_loss: 2.0230e-06 - val_coord_loss: 0.3071 - val_classes_loss: 0.6922 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5785 - val_classes_accuracy: 0.7810
# Epoch 50/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.3710 - p_loss: 1.3583e-06 - coord_loss: 0.1762 - classes_loss: 0.1948 - p_accuracy: 1.0000 - coord_IoU: 0.6157 - classes_accuracy: 0.9364 - val_loss: 1.1051 - val_p_loss: 1.0902e-05 - val_coord_loss: 0.3228 - val_classes_loss: 0.7823 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5704 - val_classes_accuracy: 0.7619

# %%
# Analyse des résultats : courbes d'évolution de la fonction de perte, et de l'IoU des boîtes englobantes ainsi que de la précision des classes prédites
plot_training_analysis(history, metric='loss')
plot_training_analysis(history, metric='coord_IoU')
plot_training_analysis(history, metric='classes_accuracy')

# Prédiction des données de test
y_pred_presence, y_pred_coords, y_pred_classes = model.predict(x_test)
y_pred = np.zeros(y_test.shape)
for i in range(y_pred.shape[0]):
  y_pred[i, 0] = y_pred_presence[i]
  y_pred[i, 1:5] = y_pred_coords[i]
  y_pred[i, 5:] = y_pred_classes[i]

# Affichage des résultats sur plusieurs images
print_data_localisation(x_test, y_test, y_pred = y_pred, id=1, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=2, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=3, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=4, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=5, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=6, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=7, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=8, image_size=IMAGE_SIZE)

# %%
class_res, accuracy = global_accuracy(y_test, y_pred)

print(f"La précision globale est de {accuracy:.1f}%")

print()
print("------------------------------------------")
print("| Classe | Précision | Rappel | F1-score |")
print("------------------------------------------")
for i in range(num_classes):
  print(f"| {class_labels[i]:7s}|   {class_res[i]['Precision']:.2f}    |  {class_res[i]['Rappel']:.2f}  |   {class_res[i]['F-score']:.2f}   |")
  print("------------------------------------------")
# Out:
# La précision globale est de 40.8%
#
# ------------------------------------------
# | Classe | Précision | Rappel | F1-score |
# ------------------------------------------
# | MESCHA |   0.26    |  0.41  |   0.32   |
# ------------------------------------------
# | VEREUR |   0.09    |  0.09  |   0.09   |
# ------------------------------------------
# | ECUROU |   0.82    |  0.82  |   0.82   |
# ------------------------------------------
# | PIEBAV |   0.73    |  0.73  |   0.73   |
# ------------------------------------------
# | SITTOR |   0.36    |  0.23  |   0.28   |
# ------------------------------------------
# | PINARB |   0.48    |  0.55  |   0.51   |
# ------------------------------------------
# | MESNOI |   0.27    |  0.21  |   0.24   |
# ------------------------------------------
# | MESNON |   0.10    |  0.09  |   0.10   |
# ------------------------------------------
# | MESBLE |   0.40    |  0.27  |   0.32   |
# ------------------------------------------
# | ROUGOR |   0.50    |  0.43  |   0.46   |
# ------------------------------------------
# | ACCMOU |   0.45    |  0.59  |   0.51   |
# ------------------------------------------

# %% [markdown]
# En pratique, il est délicat de trouver une bonne combinaison des fonctions de perte tel que vous l'avez fait sur les cellules précédentes. L'entropie croisée et l'erreur quadratique moyenne donnent des valeurs trop différentes pour être combinables efficacement.
#
# Une variante, peut-être plus simple à faire fonctionner, est d'utiliser uniquement l'erreur quadratique moyenne comme perte pour toutes les sorties. C'est cette variante qui est implémentée dans l'algorithme YOLO, dont nous implémenterons une version simplifiée dans le prochain TP.
# Testez cette solution ci-dessous. Comme sur l'exercice précédent, n'hésitez pas à faire varier le poids des différents éléments de la fonction de coût.

# %%
batch_size=16
model = create_model_localisation()
opt = Adam(learning_rate=3e-4)  

loss = ['mse', 'mse', 'mse']
metrics =[ ['accuracy'], [iou()], ['accuracy']]
loss_weights = [1, 1, 1]

model.compile(loss=loss,
              optimizer=opt,
              metrics=metrics,
              loss_weights=loss_weights
              )
history = model.fit(x_train, [y_train[:,0], y_train[:,1:5], y_train[:,5:]],
              epochs=50,
              batch_size=batch_size,            
              validation_data=(x_val, [y_val[:,0], y_val[:,1:5], y_val[:,5:]]))
# Out:
# Epoch 1/50
# 118/118 [==============================] - 6s 32ms/step - loss: 0.8863 - p_loss: 0.0046 - coord_loss: 0.8038 - classes_loss: 0.0779 - p_accuracy: 0.9989 - coord_IoU: 0.4089 - classes_accuracy: 0.2413 - val_loss: 0.7389 - val_p_loss: 0.0025 - val_coord_loss: 0.6626 - val_classes_loss: 0.0739 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.4439 - val_classes_accuracy: 0.3810
# Epoch 2/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.6416 - p_loss: 1.8751e-04 - coord_loss: 0.5764 - classes_loss: 0.0651 - p_accuracy: 1.0000 - coord_IoU: 0.4755 - classes_accuracy: 0.4544 - val_loss: 0.6205 - val_p_loss: 0.0016 - val_coord_loss: 0.5523 - val_classes_loss: 0.0666 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.4798 - val_classes_accuracy: 0.4714
# Epoch 3/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.5494 - p_loss: 9.3415e-05 - coord_loss: 0.4905 - classes_loss: 0.0588 - p_accuracy: 1.0000 - coord_IoU: 0.5039 - classes_accuracy: 0.5048 - val_loss: 0.6015 - val_p_loss: 0.0014 - val_coord_loss: 0.5344 - val_classes_loss: 0.0658 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.4886 - val_classes_accuracy: 0.4905
# Epoch 4/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.4924 - p_loss: 6.6689e-05 - coord_loss: 0.4369 - classes_loss: 0.0554 - p_accuracy: 1.0000 - coord_IoU: 0.5193 - classes_accuracy: 0.5414 - val_loss: 0.5359 - val_p_loss: 4.7150e-04 - val_coord_loss: 0.4755 - val_classes_loss: 0.0599 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.4946 - val_classes_accuracy: 0.5190
# Epoch 5/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.4425 - p_loss: 4.1360e-05 - coord_loss: 0.3895 - classes_loss: 0.0530 - p_accuracy: 1.0000 - coord_IoU: 0.5360 - classes_accuracy: 0.5790 - val_loss: 0.5605 - val_p_loss: 1.9415e-04 - val_coord_loss: 0.5014 - val_classes_loss: 0.0589 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5367 - val_classes_accuracy: 0.5286
# Epoch 6/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.4037 - p_loss: 2.5369e-05 - coord_loss: 0.3525 - classes_loss: 0.0512 - p_accuracy: 1.0000 - coord_IoU: 0.5549 - classes_accuracy: 0.5806 - val_loss: 0.4866 - val_p_loss: 1.8085e-04 - val_coord_loss: 0.4305 - val_classes_loss: 0.0560 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5158 - val_classes_accuracy: 0.5333
# Epoch 7/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.3600 - p_loss: 3.1611e-05 - coord_loss: 0.3103 - classes_loss: 0.0496 - p_accuracy: 1.0000 - coord_IoU: 0.5755 - classes_accuracy: 0.5960 - val_loss: 0.4399 - val_p_loss: 1.1013e-04 - val_coord_loss: 0.3855 - val_classes_loss: 0.0543 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5499 - val_classes_accuracy: 0.5524
# Epoch 8/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.3291 - p_loss: 1.3199e-05 - coord_loss: 0.2814 - classes_loss: 0.0477 - p_accuracy: 1.0000 - coord_IoU: 0.5832 - classes_accuracy: 0.6029 - val_loss: 0.4264 - val_p_loss: 1.2778e-04 - val_coord_loss: 0.3729 - val_classes_loss: 0.0533 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5620 - val_classes_accuracy: 0.5524
# Epoch 9/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.2935 - p_loss: 9.3974e-06 - coord_loss: 0.2467 - classes_loss: 0.0467 - p_accuracy: 1.0000 - coord_IoU: 0.6007 - classes_accuracy: 0.6230 - val_loss: 0.4262 - val_p_loss: 1.1144e-04 - val_coord_loss: 0.3718 - val_classes_loss: 0.0543 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5583 - val_classes_accuracy: 0.5952
# Epoch 10/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.2676 - p_loss: 8.7584e-06 - coord_loss: 0.2219 - classes_loss: 0.0457 - p_accuracy: 1.0000 - coord_IoU: 0.6199 - classes_accuracy: 0.6304 - val_loss: 0.4104 - val_p_loss: 2.1396e-04 - val_coord_loss: 0.3572 - val_classes_loss: 0.0530 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5680 - val_classes_accuracy: 0.5905
# Epoch 11/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.2526 - p_loss: 1.1590e-05 - coord_loss: 0.2079 - classes_loss: 0.0447 - p_accuracy: 1.0000 - coord_IoU: 0.6245 - classes_accuracy: 0.6310 - val_loss: 0.3725 - val_p_loss: 9.6640e-05 - val_coord_loss: 0.3211 - val_classes_loss: 0.0514 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5813 - val_classes_accuracy: 0.5524
# Epoch 12/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.2347 - p_loss: 6.9145e-06 - coord_loss: 0.1914 - classes_loss: 0.0434 - p_accuracy: 1.0000 - coord_IoU: 0.6305 - classes_accuracy: 0.6463 - val_loss: 0.4340 - val_p_loss: 2.4360e-04 - val_coord_loss: 0.3811 - val_classes_loss: 0.0526 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5484 - val_classes_accuracy: 0.5667
# Epoch 13/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.2140 - p_loss: 1.1406e-05 - coord_loss: 0.1711 - classes_loss: 0.0429 - p_accuracy: 1.0000 - coord_IoU: 0.6427 - classes_accuracy: 0.6548 - val_loss: 0.3598 - val_p_loss: 5.2520e-05 - val_coord_loss: 0.3104 - val_classes_loss: 0.0494 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6015 - val_classes_accuracy: 0.5762
# Epoch 14/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.2013 - p_loss: 9.0352e-06 - coord_loss: 0.1591 - classes_loss: 0.0422 - p_accuracy: 1.0000 - coord_IoU: 0.6536 - classes_accuracy: 0.6463 - val_loss: 0.3548 - val_p_loss: 1.0652e-04 - val_coord_loss: 0.3064 - val_classes_loss: 0.0482 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5923 - val_classes_accuracy: 0.5952
# Epoch 15/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.1866 - p_loss: 9.9375e-06 - coord_loss: 0.1452 - classes_loss: 0.0414 - p_accuracy: 1.0000 - coord_IoU: 0.6646 - classes_accuracy: 0.6516 - val_loss: 0.3727 - val_p_loss: 1.1698e-04 - val_coord_loss: 0.3236 - val_classes_loss: 0.0490 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5882 - val_classes_accuracy: 0.6095
# Epoch 16/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.1632 - p_loss: 6.1430e-06 - coord_loss: 0.1234 - classes_loss: 0.0397 - p_accuracy: 1.0000 - coord_IoU: 0.6756 - classes_accuracy: 0.6744 - val_loss: 0.3551 - val_p_loss: 7.8300e-05 - val_coord_loss: 0.3077 - val_classes_loss: 0.0473 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6013 - val_classes_accuracy: 0.6048
# Epoch 17/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.1540 - p_loss: 6.6806e-06 - coord_loss: 0.1151 - classes_loss: 0.0389 - p_accuracy: 1.0000 - coord_IoU: 0.6893 - classes_accuracy: 0.6729 - val_loss: 0.3559 - val_p_loss: 3.9705e-05 - val_coord_loss: 0.3087 - val_classes_loss: 0.0472 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5873 - val_classes_accuracy: 0.6238
# Epoch 18/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.1422 - p_loss: 3.0990e-06 - coord_loss: 0.1038 - classes_loss: 0.0383 - p_accuracy: 1.0000 - coord_IoU: 0.6939 - classes_accuracy: 0.6967 - val_loss: 0.3388 - val_p_loss: 3.8350e-05 - val_coord_loss: 0.2932 - val_classes_loss: 0.0456 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5992 - val_classes_accuracy: 0.6333
# Epoch 19/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.1336 - p_loss: 5.2240e-06 - coord_loss: 0.0967 - classes_loss: 0.0368 - p_accuracy: 1.0000 - coord_IoU: 0.7047 - classes_accuracy: 0.6994 - val_loss: 0.3501 - val_p_loss: 8.3738e-05 - val_coord_loss: 0.3046 - val_classes_loss: 0.0454 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5946 - val_classes_accuracy: 0.6619
# Epoch 20/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.1265 - p_loss: 4.8953e-06 - coord_loss: 0.0903 - classes_loss: 0.0361 - p_accuracy: 1.0000 - coord_IoU: 0.7063 - classes_accuracy: 0.7264 - val_loss: 0.3297 - val_p_loss: 4.3136e-05 - val_coord_loss: 0.2852 - val_classes_loss: 0.0444 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6135 - val_classes_accuracy: 0.6381
# Epoch 21/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.1171 - p_loss: 3.7758e-06 - coord_loss: 0.0824 - classes_loss: 0.0347 - p_accuracy: 1.0000 - coord_IoU: 0.7251 - classes_accuracy: 0.7296 - val_loss: 0.3496 - val_p_loss: 6.5503e-05 - val_coord_loss: 0.3051 - val_classes_loss: 0.0445 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5805 - val_classes_accuracy: 0.6524
# Epoch 22/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.1123 - p_loss: 3.8314e-06 - coord_loss: 0.0779 - classes_loss: 0.0344 - p_accuracy: 1.0000 - coord_IoU: 0.7263 - classes_accuracy: 0.7381 - val_loss: 0.3061 - val_p_loss: 5.8380e-05 - val_coord_loss: 0.2635 - val_classes_loss: 0.0425 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6263 - val_classes_accuracy: 0.6810
# Epoch 23/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.1037 - p_loss: 5.5241e-06 - coord_loss: 0.0704 - classes_loss: 0.0333 - p_accuracy: 1.0000 - coord_IoU: 0.7306 - classes_accuracy: 0.7487 - val_loss: 0.3393 - val_p_loss: 9.0707e-05 - val_coord_loss: 0.2970 - val_classes_loss: 0.0423 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6092 - val_classes_accuracy: 0.6714
# Epoch 24/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.1020 - p_loss: 4.5036e-06 - coord_loss: 0.0696 - classes_loss: 0.0325 - p_accuracy: 1.0000 - coord_IoU: 0.7272 - classes_accuracy: 0.7487 - val_loss: 0.3092 - val_p_loss: 1.7376e-05 - val_coord_loss: 0.2679 - val_classes_loss: 0.0412 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6238 - val_classes_accuracy: 0.6571
# Epoch 25/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0951 - p_loss: 2.5166e-06 - coord_loss: 0.0637 - classes_loss: 0.0314 - p_accuracy: 1.0000 - coord_IoU: 0.7393 - classes_accuracy: 0.7683 - val_loss: 0.3205 - val_p_loss: 4.7778e-05 - val_coord_loss: 0.2794 - val_classes_loss: 0.0410 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6104 - val_classes_accuracy: 0.7190
# Epoch 26/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.0894 - p_loss: 2.5705e-06 - coord_loss: 0.0590 - classes_loss: 0.0304 - p_accuracy: 1.0000 - coord_IoU: 0.7505 - classes_accuracy: 0.7815 - val_loss: 0.3073 - val_p_loss: 1.6002e-05 - val_coord_loss: 0.2675 - val_classes_loss: 0.0398 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6129 - val_classes_accuracy: 0.7000
# Epoch 27/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.0852 - p_loss: 3.0969e-06 - coord_loss: 0.0553 - classes_loss: 0.0299 - p_accuracy: 1.0000 - coord_IoU: 0.7558 - classes_accuracy: 0.7762 - val_loss: 0.3295 - val_p_loss: 2.9655e-05 - val_coord_loss: 0.2886 - val_classes_loss: 0.0409 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6098 - val_classes_accuracy: 0.6857
# Epoch 28/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.0806 - p_loss: 3.0569e-06 - coord_loss: 0.0519 - classes_loss: 0.0287 - p_accuracy: 1.0000 - coord_IoU: 0.7588 - classes_accuracy: 0.7943 - val_loss: 0.3152 - val_p_loss: 5.1196e-05 - val_coord_loss: 0.2749 - val_classes_loss: 0.0402 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6222 - val_classes_accuracy: 0.7238
# Epoch 29/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.0775 - p_loss: 3.4684e-06 - coord_loss: 0.0499 - classes_loss: 0.0276 - p_accuracy: 1.0000 - coord_IoU: 0.7636 - classes_accuracy: 0.8081 - val_loss: 0.3300 - val_p_loss: 5.1708e-05 - val_coord_loss: 0.2904 - val_classes_loss: 0.0396 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5988 - val_classes_accuracy: 0.7095
# Epoch 30/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.0748 - p_loss: 3.3850e-06 - coord_loss: 0.0483 - classes_loss: 0.0265 - p_accuracy: 1.0000 - coord_IoU: 0.7705 - classes_accuracy: 0.8139 - val_loss: 0.3319 - val_p_loss: 1.5425e-05 - val_coord_loss: 0.2928 - val_classes_loss: 0.0390 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6139 - val_classes_accuracy: 0.7190
# Epoch 31/50
# 118/118 [==============================] - 3s 28ms/step - loss: 0.0718 - p_loss: 2.3962e-06 - coord_loss: 0.0458 - classes_loss: 0.0260 - p_accuracy: 1.0000 - coord_IoU: 0.7699 - classes_accuracy: 0.8171 - val_loss: 0.3144 - val_p_loss: 3.6686e-05 - val_coord_loss: 0.2766 - val_classes_loss: 0.0377 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6132 - val_classes_accuracy: 0.7286
# Epoch 32/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0679 - p_loss: 3.1571e-06 - coord_loss: 0.0431 - classes_loss: 0.0247 - p_accuracy: 1.0000 - coord_IoU: 0.7752 - classes_accuracy: 0.8303 - val_loss: 0.3268 - val_p_loss: 5.1865e-05 - val_coord_loss: 0.2888 - val_classes_loss: 0.0380 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5986 - val_classes_accuracy: 0.7238
# Epoch 33/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0684 - p_loss: 2.9835e-06 - coord_loss: 0.0442 - classes_loss: 0.0242 - p_accuracy: 1.0000 - coord_IoU: 0.7775 - classes_accuracy: 0.8303 - val_loss: 0.3233 - val_p_loss: 5.6698e-05 - val_coord_loss: 0.2859 - val_classes_loss: 0.0373 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6136 - val_classes_accuracy: 0.7238
# Epoch 34/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0651 - p_loss: 3.8230e-06 - coord_loss: 0.0416 - classes_loss: 0.0235 - p_accuracy: 1.0000 - coord_IoU: 0.7810 - classes_accuracy: 0.8415 - val_loss: 0.3253 - val_p_loss: 2.8866e-05 - val_coord_loss: 0.2875 - val_classes_loss: 0.0378 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5986 - val_classes_accuracy: 0.7190
# Epoch 35/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0613 - p_loss: 1.4920e-06 - coord_loss: 0.0389 - classes_loss: 0.0224 - p_accuracy: 1.0000 - coord_IoU: 0.7890 - classes_accuracy: 0.8547 - val_loss: 0.3009 - val_p_loss: 9.7177e-06 - val_coord_loss: 0.2642 - val_classes_loss: 0.0367 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6348 - val_classes_accuracy: 0.7143
# Epoch 36/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0619 - p_loss: 2.1928e-06 - coord_loss: 0.0402 - classes_loss: 0.0217 - p_accuracy: 1.0000 - coord_IoU: 0.7821 - classes_accuracy: 0.8531 - val_loss: 0.3094 - val_p_loss: 1.4431e-05 - val_coord_loss: 0.2737 - val_classes_loss: 0.0357 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6208 - val_classes_accuracy: 0.7476
# Epoch 37/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0597 - p_loss: 1.7400e-06 - coord_loss: 0.0388 - classes_loss: 0.0209 - p_accuracy: 1.0000 - coord_IoU: 0.7812 - classes_accuracy: 0.8669 - val_loss: 0.3043 - val_p_loss: 1.4535e-05 - val_coord_loss: 0.2688 - val_classes_loss: 0.0355 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6223 - val_classes_accuracy: 0.7429
# Epoch 38/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0552 - p_loss: 1.7055e-06 - coord_loss: 0.0354 - classes_loss: 0.0198 - p_accuracy: 1.0000 - coord_IoU: 0.7883 - classes_accuracy: 0.8712 - val_loss: 0.3091 - val_p_loss: 2.5099e-05 - val_coord_loss: 0.2738 - val_classes_loss: 0.0353 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6056 - val_classes_accuracy: 0.7381
# Epoch 39/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0547 - p_loss: 1.8526e-06 - coord_loss: 0.0357 - classes_loss: 0.0190 - p_accuracy: 1.0000 - coord_IoU: 0.7947 - classes_accuracy: 0.8775 - val_loss: 0.3106 - val_p_loss: 6.4115e-06 - val_coord_loss: 0.2766 - val_classes_loss: 0.0340 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6175 - val_classes_accuracy: 0.7667
# Epoch 40/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0522 - p_loss: 1.6665e-06 - coord_loss: 0.0343 - classes_loss: 0.0180 - p_accuracy: 1.0000 - coord_IoU: 0.7965 - classes_accuracy: 0.8908 - val_loss: 0.3238 - val_p_loss: 3.1692e-05 - val_coord_loss: 0.2903 - val_classes_loss: 0.0335 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6024 - val_classes_accuracy: 0.7619
# Epoch 41/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0507 - p_loss: 1.6315e-06 - coord_loss: 0.0332 - classes_loss: 0.0174 - p_accuracy: 1.0000 - coord_IoU: 0.8014 - classes_accuracy: 0.8982 - val_loss: 0.3081 - val_p_loss: 1.0846e-05 - val_coord_loss: 0.2736 - val_classes_loss: 0.0344 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6193 - val_classes_accuracy: 0.7381
# Epoch 42/50
# 118/118 [==============================] - 3s 30ms/step - loss: 0.0499 - p_loss: 1.5040e-06 - coord_loss: 0.0335 - classes_loss: 0.0164 - p_accuracy: 1.0000 - coord_IoU: 0.8015 - classes_accuracy: 0.9067 - val_loss: 0.3218 - val_p_loss: 2.2551e-05 - val_coord_loss: 0.2877 - val_classes_loss: 0.0341 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6169 - val_classes_accuracy: 0.7381
# Epoch 43/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0504 - p_loss: 1.2031e-06 - coord_loss: 0.0342 - classes_loss: 0.0162 - p_accuracy: 1.0000 - coord_IoU: 0.7947 - classes_accuracy: 0.9040 - val_loss: 0.2945 - val_p_loss: 1.0477e-05 - val_coord_loss: 0.2619 - val_classes_loss: 0.0326 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6327 - val_classes_accuracy: 0.7333
# Epoch 44/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0484 - p_loss: 1.3299e-06 - coord_loss: 0.0333 - classes_loss: 0.0151 - p_accuracy: 1.0000 - coord_IoU: 0.7989 - classes_accuracy: 0.9162 - val_loss: 0.2977 - val_p_loss: 4.7625e-06 - val_coord_loss: 0.2656 - val_classes_loss: 0.0321 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6315 - val_classes_accuracy: 0.7905
# Epoch 45/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0511 - p_loss: 8.3888e-07 - coord_loss: 0.0363 - classes_loss: 0.0148 - p_accuracy: 1.0000 - coord_IoU: 0.7983 - classes_accuracy: 0.9173 - val_loss: 0.3125 - val_p_loss: 8.8377e-06 - val_coord_loss: 0.2800 - val_classes_loss: 0.0325 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6039 - val_classes_accuracy: 0.7667
# Epoch 46/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0499 - p_loss: 1.2059e-06 - coord_loss: 0.0363 - classes_loss: 0.0136 - p_accuracy: 1.0000 - coord_IoU: 0.7940 - classes_accuracy: 0.9247 - val_loss: 0.3137 - val_p_loss: 1.6273e-05 - val_coord_loss: 0.2813 - val_classes_loss: 0.0324 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6020 - val_classes_accuracy: 0.7571
# Epoch 47/50
# 118/118 [==============================] - 4s 30ms/step - loss: 0.0498 - p_loss: 1.5483e-06 - coord_loss: 0.0362 - classes_loss: 0.0136 - p_accuracy: 1.0000 - coord_IoU: 0.7922 - classes_accuracy: 0.9236 - val_loss: 0.3182 - val_p_loss: 1.1665e-05 - val_coord_loss: 0.2857 - val_classes_loss: 0.0324 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6192 - val_classes_accuracy: 0.7714
# Epoch 48/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0446 - p_loss: 1.0620e-06 - coord_loss: 0.0321 - classes_loss: 0.0125 - p_accuracy: 1.0000 - coord_IoU: 0.8032 - classes_accuracy: 0.9300 - val_loss: 0.3026 - val_p_loss: 6.4168e-06 - val_coord_loss: 0.2711 - val_classes_loss: 0.0314 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6248 - val_classes_accuracy: 0.7810
# Epoch 49/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0437 - p_loss: 6.0385e-07 - coord_loss: 0.0318 - classes_loss: 0.0118 - p_accuracy: 1.0000 - coord_IoU: 0.8047 - classes_accuracy: 0.9401 - val_loss: 0.3087 - val_p_loss: 6.0122e-06 - val_coord_loss: 0.2785 - val_classes_loss: 0.0302 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6198 - val_classes_accuracy: 0.7714
# Epoch 50/50
# 118/118 [==============================] - 3s 29ms/step - loss: 0.0442 - p_loss: 7.5862e-07 - coord_loss: 0.0327 - classes_loss: 0.0115 - p_accuracy: 1.0000 - coord_IoU: 0.8030 - classes_accuracy: 0.9411 - val_loss: 0.3180 - val_p_loss: 3.0947e-06 - val_coord_loss: 0.2865 - val_classes_loss: 0.0315 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6193 - val_classes_accuracy: 0.7667

# %%
# Analyse des résultats : courbes d'évolution de la fonction de perte, et de l'IoU des boîtes englobantes ainsi que de la précision des classes prédites
plot_training_analysis(history, metric='loss')
plot_training_analysis(history, metric='coord_IoU')
plot_training_analysis(history, metric='classes_accuracy')

# Prédiction des données de test
y_pred_presence, y_pred_coords, y_pred_classes = model.predict(x_test)
y_pred = np.zeros(y_test.shape)
for i in range(y_pred.shape[0]):
  y_pred[i, 0] = y_pred_presence[i]
  y_pred[i, 1:5] = y_pred_coords[i]
  y_pred[i, 5:] = y_pred_classes[i]

# Affichage des résultats sur plusieurs images
print_data_localisation(x_test, y_test, y_pred = y_pred, id=1, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=2, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=3, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=4, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=5, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=6, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=7, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=8, image_size=IMAGE_SIZE)


class_res, accuracy = global_accuracy(y_test, y_pred, iou_thres=0.4)

print(f"La précision globale est de {accuracy:.1f}%")

print()
print("------------------------------------------")
print("| Classe | Précision | Rappel | F1-score |")
print("------------------------------------------")
for i in range(num_classes):
  print(f"| {class_labels[i]:7s}|   {class_res[i]['Precision']:.2f}    |  {class_res[i]['Rappel']:.2f}  |   {class_res[i]['F-score']:.2f}   |")
  print("------------------------------------------")
# Out:
# La précision globale est de 60.1%
#
# ------------------------------------------
# | Classe | Précision | Rappel | F1-score |
# ------------------------------------------
# | MESCHA |   0.30    |  0.27  |   0.29   |
# ------------------------------------------
# | VEREUR |   0.77    |  0.77  |   0.77   |
# ------------------------------------------
# | ECUROU |   1.00    |  0.95  |   0.98   |
# ------------------------------------------
# | PIEBAV |   0.95    |  0.95  |   0.95   |
# ------------------------------------------
# | SITTOR |   0.53    |  0.36  |   0.43   |
# ------------------------------------------
# | PINARB |   0.61    |  0.77  |   0.68   |
# ------------------------------------------
# | MESNOI |   0.36    |  0.29  |   0.32   |
# ------------------------------------------
# | MESNON |   0.27    |  0.36  |   0.31   |
# ------------------------------------------
# | MESBLE |   0.29    |  0.23  |   0.26   |
# ------------------------------------------
# | ROUGOR |   0.73    |  0.76  |   0.74   |
# ------------------------------------------
# | ACCMOU |   0.68    |  0.77  |   0.72   |
# ------------------------------------------

# %% [markdown]
# Compte-tenu de la taille réduite de la base de données, les résultats ne sont pas mal du tout ! On observe quelques confusions entre certaines classes mais les prédictions sont souvent intéressantes.
#
# Il devrait cependant subsister un fort surapprentissage à ce stade. Comme nous l'avons vu dans de précédents TPs, vous avez plusieurs possibilités qui s'offrent à vous pour le corriger :
#
# *   Augmentation de la base de données. Vous pouvez pour cela vous appuyer sur l'exemple fourni en TP précédent, avec une classe *Sequence* et l'utilisation de la librairie *Albumentation*. Je vous fournis une Sequence qui fonctionne ci-dessous.
# *   Utilisation de *transfer learning* : partant d'un réseau entraîné sur ImageNet (qui contient de nombreuses classes d'animaux), vous bénéficieriez de filtres très généraux qui aiderait à limiter le surapprentissage.

# %% [markdown]
# # Correction des exercices complémentaires
#
# L'augmentation seule aide déjà un peu, mais le transfer learning accompagné d'augmentation de données donne les meilleurs résultats, avec presque 80% de bonnes détections !

# %% [markdown]
# ## Augmentation de données

# %% [markdown]
# Il y a des problèmes avec les verions d'openCV et d'Albumentation, voici comment les résoudre :

# %%
# !pip uninstall opencv-python-headless==4.5.5.62
# !pip install opencv-python-headless==4.1.2.30
# !pip install -q -U albumentations
# !echo "$(pip freeze | grep albumentations) is successfully installed"
# Out:
# WARNING: Skipping opencv-python-headless as it is not installed.
# Collecting opencv-python-headless==4.1.2.30
#   Downloading opencv_python_headless-4.1.2.30-cp37-cp37m-manylinux1_x86_64.whl (21.8 MB)
#      |████████████████████████████████| 21.8 MB 148 kB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python-headless==4.1.2.30) (1.21.5)
# Installing collected packages: opencv-python-headless
# Successfully installed opencv-python-headless-4.1.2.30
#      |████████████████████████████████| 102 kB 14.3 MB/s
# albumentations==1.1.0 is successfully installed

# %% [markdown]
# Définition des augmentations (uniquement colorimétriques ici)

# %%
from albumentations import (Compose, RandomBrightness, RandomContrast, RandomGamma, ShiftScaleRotate, RandomSizedBBoxSafeCrop)
import albumentations as A

AUGMENTATIONS_TRAIN = Compose([
    RandomContrast(limit=0.2, p=0.5),
    RandomGamma(gamma_limit=(80, 120), p=0.5),
    RandomBrightness(limit=0.2, p=0.5)
], bbox_params=A.BboxParams(format='yolo', label_fields=['class_labels']))
# Out:
# /usr/local/lib/python3.7/dist-packages/albumentations/augmentations/transforms.py:1828: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/albumentations/augmentations/transforms.py:1802: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   FutureWarning,

# %% [markdown]
# Une sequence qui permet d'implanter l'augmentation de données :

# %%
from tensorflow.keras.utils import Sequence

class MangeoireSequence(Sequence):
    # Initialisation de la séquence avec différents paramètres
    def __init__(self, x_set, y_set, batch_size,augmentations):
        self.x, self.y = x_set, y_set
        self.classes = ['MESCHA', 'VEREUR', 'ECUROU', 'PIEBAV', 'SITTOR', 'PINARB', 'MESNOI', 'MESNON', 'MESBLE', 'ROUGOR', 'ACCMOU']
        self.batch_size = batch_size
        self.augment = augmentations
        self.indices1 = np.arange(x_set.shape[0]) 
        np.random.shuffle(self.indices1) # Les indices permettent d'accéder
        # aux données et sont randomisés à chaque epoch pour varier la composition
        # des batches au cours de l'entraînement

    # Fonction calculant le nombre de pas de descente du gradient par epoch
    def __len__(self):
        return int(np.ceil(len(self.x) / float(self.batch_size)))

    # Il y a des problèmes d'arrondi dans les conversions de boîtes englobantes 
    # internes à la librairie Albumentations
    # Pour les contourner, si les boîtes sont trop proches des bords, on les érode un peu
    def erode_bounding_box(self, box):
        epsilon = 0.01
        
        xmin = max(box[0] - box[2]/2, epsilon)
        ymin = max(box[1] - box[3]/2, epsilon)
        xmax = min(box[0] + box[2]/2, 1-epsilon)
        ymax = min(box[1] + box[3]/2, 1-epsilon)
        
        cx = xmin + (xmax - xmin)/2
        cy = ymin + (ymax - ymin)/2
        width = xmax - xmin
        height = ymax - ymin
        
        return np.array([cx, cy, width, height])
    
    # Application de l'augmentation de données à chaque image du batch et aux
    # boîtes englobantes associées
    def apply_augmentation(self, bx, by):

        batch_x = np.zeros((bx.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
        batch_y = by
        
        # Pour chaque image du batch
        for i in range(len(bx)):
            bboxes = []
            box = by[i,1:5]
            # Dénormalisation des coordonnées de boites englobantes
            box[0] = (box[0]*y_std[1] + y_mean[1])
            box[1] = (box[1]*y_std[2] + y_mean[2])
            box[2] = (box[2]*y_std[3] + y_mean[3])
            box[3] = (box[3]*y_std[4] + y_mean[4])
            box = self.erode_bounding_box(box)
            bboxes.append(box)
            
            class_labels = []
            class_id = np.argmax(by[i, 5:])
            class_labels.append(self.classes[class_id])

            img = bx[i]

            # Application de l'augmentation à l'image et aux masques
            transformed = self.augment(image=img.astype('float32'), bboxes=bboxes, class_labels=class_labels)
            batch_x[i] = transformed['image']
            batch_y_transformed = transformed['bboxes']
                
            # Renormalisation des coordonnées de boîte englobante transformée
            batch_y[i, 1] = (batch_y_transformed[0][0] - y_mean[1])/y_std[1]
            batch_y[i, 2] = (batch_y_transformed[0][1] - y_mean[2])/y_std[2]
            batch_y[i, 3] = (batch_y_transformed[0][2] - y_mean[3])/y_std[3]
            batch_y[i, 4] = (batch_y_transformed[0][3] - y_mean[4])/y_std[4]

        return batch_x, batch_y

    # Fonction appelée à chaque nouveau batch : sélection et augmentation des données
    def __getitem__(self, idx):
        batch_x = self.x[self.indices1[idx * self.batch_size:(idx + 1) * self.batch_size]]
        batch_y = self.y[self.indices1[idx * self.batch_size:(idx + 1) * self.batch_size]]
        batch_x, batch_y = self.apply_augmentation(batch_x, batch_y)
        
        batch_y = np.array(batch_y)
        return np.array(batch_x), [batch_y[:,0], batch_y[:,1:5], batch_y[:,5:]]

    # Fonction appelée à la fin d'un epoch ; on randomise les indices d'accès aux données
    def on_epoch_end(self):
        np.random.shuffle(self.indices1)

# %%
# Instanciation d'une Sequence
train_gen = MangeoireSequence(x_train, y_train, 16, augmentations=AUGMENTATIONS_TRAIN)

# Pour tester la séquence, nous sélectionnons les éléments du premier batch et les affichons
batch_x, batch_y = train_gen.__getitem__(0)

y_batch = np.zeros((batch_y[0].shape[0],1+4+num_classes))

for i in range(batch_y[0].shape[0]):
  y_batch[i, 0] = batch_y[0][i]
  y_batch[i, 1:5] = batch_y[1][i]
  y_batch[i, 5:] = batch_y[2][i]

print_data_localisation(batch_x, y_batch, image_size=IMAGE_SIZE)

# %%
batch_size=16
model = create_model_localisation()
opt = Adam(learning_rate=3e-4)  

loss=['binary_crossentropy', 'mse', 'categorical_crossentropy']
metrics=[ ['accuracy'], [iou()], ['accuracy']]
loss_weights = [1, 5, 1]

train_gen = MangeoireSequence(x_train, y_train, 16, augmentations=AUGMENTATIONS_TRAIN)


model.compile(loss=loss,
              optimizer=opt,
              metrics=metrics,
              loss_weights=loss_weights
              )

history = model.fit(train_gen,
              epochs=50,
              batch_size=batch_size,            
              validation_data=(x_val, [y_val[:,0], y_val[:,1:5], y_val[:,5:]]))
# Out:
# Epoch 1/50
# 118/118 [==============================] - 8s 47ms/step - loss: 6.9018 - p_loss: 0.0624 - coord_loss: 0.9246 - classes_loss: 2.2165 - p_accuracy: 0.9963 - coord_IoU: 0.3999 - classes_accuracy: 0.2519 - val_loss: 5.4838 - val_p_loss: 0.0238 - val_coord_loss: 0.6941 - val_classes_loss: 1.9894 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.4356 - val_classes_accuracy: 0.4238
# Epoch 2/50
# 118/118 [==============================] - 7s 57ms/step - loss: 4.6133 - p_loss: 0.0028 - coord_loss: 0.5972 - classes_loss: 1.6247 - p_accuracy: 1.0000 - coord_IoU: 0.4702 - classes_accuracy: 0.4634 - val_loss: 4.7109 - val_p_loss: 0.0069 - val_coord_loss: 0.6141 - val_classes_loss: 1.6337 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.4325 - val_classes_accuracy: 0.4762
# Epoch 3/50
# 118/118 [==============================] - 4s 35ms/step - loss: 3.9980 - p_loss: 0.0011 - coord_loss: 0.5214 - classes_loss: 1.3896 - p_accuracy: 1.0000 - coord_IoU: 0.4863 - classes_accuracy: 0.5101 - val_loss: 4.3404 - val_p_loss: 0.0049 - val_coord_loss: 0.5736 - val_classes_loss: 1.4677 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.4447 - val_classes_accuracy: 0.5048
# Epoch 4/50
# 118/118 [==============================] - 4s 32ms/step - loss: 3.6259 - p_loss: 8.3880e-04 - coord_loss: 0.4686 - classes_loss: 1.2821 - p_accuracy: 1.0000 - coord_IoU: 0.5024 - classes_accuracy: 0.5451 - val_loss: 3.7486 - val_p_loss: 0.0037 - val_coord_loss: 0.4798 - val_classes_loss: 1.3462 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5229 - val_classes_accuracy: 0.5381
# Epoch 5/50
# 118/118 [==============================] - 4s 31ms/step - loss: 3.3084 - p_loss: 4.6916e-04 - coord_loss: 0.4225 - classes_loss: 1.1953 - p_accuracy: 1.0000 - coord_IoU: 0.5189 - classes_accuracy: 0.5514 - val_loss: 3.5523 - val_p_loss: 0.0017 - val_coord_loss: 0.4523 - val_classes_loss: 1.2892 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5006 - val_classes_accuracy: 0.5190
# Epoch 6/50
# 118/118 [==============================] - 4s 32ms/step - loss: 3.0450 - p_loss: 2.7478e-04 - coord_loss: 0.3819 - classes_loss: 1.1350 - p_accuracy: 1.0000 - coord_IoU: 0.5423 - classes_accuracy: 0.5875 - val_loss: 3.5712 - val_p_loss: 0.0016 - val_coord_loss: 0.4642 - val_classes_loss: 1.2484 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5214 - val_classes_accuracy: 0.5762
# Epoch 7/50
# 118/118 [==============================] - 4s 31ms/step - loss: 2.8455 - p_loss: 2.5028e-04 - coord_loss: 0.3483 - classes_loss: 1.1037 - p_accuracy: 1.0000 - coord_IoU: 0.5531 - classes_accuracy: 0.6013 - val_loss: 3.3038 - val_p_loss: 6.8904e-04 - val_coord_loss: 0.4232 - val_classes_loss: 1.1870 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5424 - val_classes_accuracy: 0.5571
# Epoch 8/50
# 118/118 [==============================] - 4s 31ms/step - loss: 2.6539 - p_loss: 1.3327e-04 - coord_loss: 0.3233 - classes_loss: 1.0372 - p_accuracy: 1.0000 - coord_IoU: 0.5641 - classes_accuracy: 0.6103 - val_loss: 3.2317 - val_p_loss: 9.0205e-04 - val_coord_loss: 0.4158 - val_classes_loss: 1.1520 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5445 - val_classes_accuracy: 0.5810
# Epoch 9/50
# 118/118 [==============================] - 4s 32ms/step - loss: 2.4818 - p_loss: 1.2547e-04 - coord_loss: 0.2980 - classes_loss: 0.9919 - p_accuracy: 1.0000 - coord_IoU: 0.5728 - classes_accuracy: 0.6341 - val_loss: 3.0223 - val_p_loss: 7.0793e-04 - val_coord_loss: 0.3824 - val_classes_loss: 1.1096 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5565 - val_classes_accuracy: 0.5952
# Epoch 10/50
# 118/118 [==============================] - 4s 31ms/step - loss: 2.3083 - p_loss: 9.5947e-05 - coord_loss: 0.2689 - classes_loss: 0.9639 - p_accuracy: 1.0000 - coord_IoU: 0.5875 - classes_accuracy: 0.6448 - val_loss: 2.9768 - val_p_loss: 6.1046e-04 - val_coord_loss: 0.3855 - val_classes_loss: 1.0488 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5561 - val_classes_accuracy: 0.6048
# Epoch 11/50
# 118/118 [==============================] - 4s 32ms/step - loss: 2.1818 - p_loss: 7.2355e-05 - coord_loss: 0.2523 - classes_loss: 0.9202 - p_accuracy: 1.0000 - coord_IoU: 0.5982 - classes_accuracy: 0.6734 - val_loss: 2.8500 - val_p_loss: 3.9764e-04 - val_coord_loss: 0.3568 - val_classes_loss: 1.0655 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5783 - val_classes_accuracy: 0.6048
# Epoch 12/50
# 118/118 [==============================] - 4s 32ms/step - loss: 2.0729 - p_loss: 7.0239e-05 - coord_loss: 0.2385 - classes_loss: 0.8802 - p_accuracy: 1.0000 - coord_IoU: 0.5961 - classes_accuracy: 0.6861 - val_loss: 2.8342 - val_p_loss: 4.0725e-04 - val_coord_loss: 0.3586 - val_classes_loss: 1.0406 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5487 - val_classes_accuracy: 0.6190
# Epoch 13/50
# 118/118 [==============================] - 5s 40ms/step - loss: 1.9303 - p_loss: 6.5331e-05 - coord_loss: 0.2184 - classes_loss: 0.8381 - p_accuracy: 1.0000 - coord_IoU: 0.6136 - classes_accuracy: 0.6877 - val_loss: 2.8605 - val_p_loss: 6.3642e-04 - val_coord_loss: 0.3694 - val_classes_loss: 1.0126 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5655 - val_classes_accuracy: 0.6333
# Epoch 14/50
# 118/118 [==============================] - 4s 32ms/step - loss: 1.8617 - p_loss: 5.3594e-05 - coord_loss: 0.2064 - classes_loss: 0.8295 - p_accuracy: 1.0000 - coord_IoU: 0.6184 - classes_accuracy: 0.6850 - val_loss: 2.8213 - val_p_loss: 2.4890e-04 - val_coord_loss: 0.3628 - val_classes_loss: 1.0071 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5598 - val_classes_accuracy: 0.6333
# Epoch 15/50
# 118/118 [==============================] - 4s 32ms/step - loss: 1.7651 - p_loss: 3.6857e-05 - coord_loss: 0.1955 - classes_loss: 0.7875 - p_accuracy: 1.0000 - coord_IoU: 0.6201 - classes_accuracy: 0.7031 - val_loss: 2.4707 - val_p_loss: 1.3567e-04 - val_coord_loss: 0.3113 - val_classes_loss: 0.9143 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6014 - val_classes_accuracy: 0.6524
# Epoch 16/50
# 118/118 [==============================] - 4s 33ms/step - loss: 1.6432 - p_loss: 2.8921e-05 - coord_loss: 0.1824 - classes_loss: 0.7312 - p_accuracy: 1.0000 - coord_IoU: 0.6258 - classes_accuracy: 0.7402 - val_loss: 2.6229 - val_p_loss: 2.9430e-04 - val_coord_loss: 0.3355 - val_classes_loss: 0.9450 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5765 - val_classes_accuracy: 0.6571
# Epoch 17/50
# 118/118 [==============================] - 4s 33ms/step - loss: 1.5883 - p_loss: 3.8858e-05 - coord_loss: 0.1756 - classes_loss: 0.7102 - p_accuracy: 1.0000 - coord_IoU: 0.6334 - classes_accuracy: 0.7460 - val_loss: 2.5343 - val_p_loss: 7.0884e-05 - val_coord_loss: 0.3222 - val_classes_loss: 0.9229 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5788 - val_classes_accuracy: 0.6714
# Epoch 18/50
# 118/118 [==============================] - 4s 32ms/step - loss: 1.4765 - p_loss: 2.8701e-05 - coord_loss: 0.1604 - classes_loss: 0.6745 - p_accuracy: 1.0000 - coord_IoU: 0.6439 - classes_accuracy: 0.7635 - val_loss: 2.4868 - val_p_loss: 2.0439e-04 - val_coord_loss: 0.3259 - val_classes_loss: 0.8573 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5744 - val_classes_accuracy: 0.7048
# Epoch 19/50
# 118/118 [==============================] - 4s 31ms/step - loss: 1.3801 - p_loss: 2.9759e-05 - coord_loss: 0.1509 - classes_loss: 0.6255 - p_accuracy: 1.0000 - coord_IoU: 0.6440 - classes_accuracy: 0.7805 - val_loss: 2.3531 - val_p_loss: 8.6448e-05 - val_coord_loss: 0.3048 - val_classes_loss: 0.8292 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5977 - val_classes_accuracy: 0.7143
# Epoch 20/50
# 118/118 [==============================] - 4s 32ms/step - loss: 1.3277 - p_loss: 1.7373e-05 - coord_loss: 0.1444 - classes_loss: 0.6055 - p_accuracy: 1.0000 - coord_IoU: 0.6487 - classes_accuracy: 0.8028 - val_loss: 2.4243 - val_p_loss: 1.0581e-04 - val_coord_loss: 0.3204 - val_classes_loss: 0.8220 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5713 - val_classes_accuracy: 0.6905
# Epoch 21/50
# 118/118 [==============================] - 4s 32ms/step - loss: 1.2436 - p_loss: 1.4248e-05 - coord_loss: 0.1364 - classes_loss: 0.5615 - p_accuracy: 1.0000 - coord_IoU: 0.6558 - classes_accuracy: 0.8081 - val_loss: 2.4659 - val_p_loss: 5.8882e-05 - val_coord_loss: 0.3289 - val_classes_loss: 0.8213 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5573 - val_classes_accuracy: 0.6952
# Epoch 22/50
# 118/118 [==============================] - 4s 32ms/step - loss: 1.1584 - p_loss: 1.4629e-05 - coord_loss: 0.1245 - classes_loss: 0.5360 - p_accuracy: 1.0000 - coord_IoU: 0.6629 - classes_accuracy: 0.8081 - val_loss: 2.2494 - val_p_loss: 5.5301e-05 - val_coord_loss: 0.2930 - val_classes_loss: 0.7844 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6063 - val_classes_accuracy: 0.7000
# Epoch 23/50
# 118/118 [==============================] - 4s 32ms/step - loss: 1.0993 - p_loss: 1.2455e-05 - coord_loss: 0.1193 - classes_loss: 0.5026 - p_accuracy: 1.0000 - coord_IoU: 0.6690 - classes_accuracy: 0.8256 - val_loss: 2.2237 - val_p_loss: 3.5618e-05 - val_coord_loss: 0.2932 - val_classes_loss: 0.7577 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6029 - val_classes_accuracy: 0.7476
# Epoch 24/50
# 118/118 [==============================] - 4s 32ms/step - loss: 1.0137 - p_loss: 1.2334e-05 - coord_loss: 0.1098 - classes_loss: 0.4647 - p_accuracy: 1.0000 - coord_IoU: 0.6820 - classes_accuracy: 0.8409 - val_loss: 2.2038 - val_p_loss: 9.3587e-05 - val_coord_loss: 0.2935 - val_classes_loss: 0.7360 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6018 - val_classes_accuracy: 0.7238
# Epoch 25/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.9878 - p_loss: 1.4748e-05 - coord_loss: 0.1101 - classes_loss: 0.4375 - p_accuracy: 1.0000 - coord_IoU: 0.6758 - classes_accuracy: 0.8579 - val_loss: 2.1237 - val_p_loss: 5.1181e-05 - val_coord_loss: 0.2794 - val_classes_loss: 0.7267 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5904 - val_classes_accuracy: 0.7238
# Epoch 26/50
# 118/118 [==============================] - 4s 31ms/step - loss: 0.9457 - p_loss: 1.0878e-05 - coord_loss: 0.1065 - classes_loss: 0.4132 - p_accuracy: 1.0000 - coord_IoU: 0.6813 - classes_accuracy: 0.8674 - val_loss: 2.1759 - val_p_loss: 4.5062e-05 - val_coord_loss: 0.2902 - val_classes_loss: 0.7248 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6006 - val_classes_accuracy: 0.7095
# Epoch 27/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.8862 - p_loss: 1.0918e-05 - coord_loss: 0.1006 - classes_loss: 0.3832 - p_accuracy: 1.0000 - coord_IoU: 0.6876 - classes_accuracy: 0.8770 - val_loss: 2.1601 - val_p_loss: 5.0122e-05 - val_coord_loss: 0.2893 - val_classes_loss: 0.7138 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5935 - val_classes_accuracy: 0.7381
# Epoch 28/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.8769 - p_loss: 1.2662e-05 - coord_loss: 0.1036 - classes_loss: 0.3588 - p_accuracy: 1.0000 - coord_IoU: 0.6847 - classes_accuracy: 0.8924 - val_loss: 2.3482 - val_p_loss: 7.2135e-05 - val_coord_loss: 0.3209 - val_classes_loss: 0.7434 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5885 - val_classes_accuracy: 0.7238
# Epoch 29/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.7933 - p_loss: 8.3403e-06 - coord_loss: 0.0950 - classes_loss: 0.3184 - p_accuracy: 1.0000 - coord_IoU: 0.6963 - classes_accuracy: 0.9077 - val_loss: 2.1703 - val_p_loss: 6.0158e-05 - val_coord_loss: 0.2925 - val_classes_loss: 0.7079 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6116 - val_classes_accuracy: 0.7333
# Epoch 30/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.7879 - p_loss: 7.0463e-06 - coord_loss: 0.0952 - classes_loss: 0.3117 - p_accuracy: 1.0000 - coord_IoU: 0.6929 - classes_accuracy: 0.9088 - val_loss: 2.1040 - val_p_loss: 5.2522e-05 - val_coord_loss: 0.2903 - val_classes_loss: 0.6524 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6054 - val_classes_accuracy: 0.7762
# Epoch 31/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.6967 - p_loss: 6.4080e-06 - coord_loss: 0.0846 - classes_loss: 0.2736 - p_accuracy: 1.0000 - coord_IoU: 0.7051 - classes_accuracy: 0.9221 - val_loss: 2.0805 - val_p_loss: 8.4253e-05 - val_coord_loss: 0.2835 - val_classes_loss: 0.6629 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5955 - val_classes_accuracy: 0.7476
# Epoch 32/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.6675 - p_loss: 5.8088e-06 - coord_loss: 0.0828 - classes_loss: 0.2534 - p_accuracy: 1.0000 - coord_IoU: 0.7092 - classes_accuracy: 0.9348 - val_loss: 2.2669 - val_p_loss: 6.5477e-05 - val_coord_loss: 0.3119 - val_classes_loss: 0.7075 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5966 - val_classes_accuracy: 0.7190
# Epoch 33/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.6233 - p_loss: 5.2749e-06 - coord_loss: 0.0784 - classes_loss: 0.2311 - p_accuracy: 1.0000 - coord_IoU: 0.7134 - classes_accuracy: 0.9459 - val_loss: 2.1181 - val_p_loss: 4.7198e-05 - val_coord_loss: 0.2918 - val_classes_loss: 0.6588 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6068 - val_classes_accuracy: 0.7429
# Epoch 34/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.6065 - p_loss: 6.9171e-06 - coord_loss: 0.0790 - classes_loss: 0.2117 - p_accuracy: 1.0000 - coord_IoU: 0.7121 - classes_accuracy: 0.9533 - val_loss: 2.1098 - val_p_loss: 1.4886e-05 - val_coord_loss: 0.2977 - val_classes_loss: 0.6211 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6179 - val_classes_accuracy: 0.7667
# Epoch 35/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.5846 - p_loss: 3.9826e-06 - coord_loss: 0.0764 - classes_loss: 0.2026 - p_accuracy: 1.0000 - coord_IoU: 0.7189 - classes_accuracy: 0.9549 - val_loss: 2.0093 - val_p_loss: 2.0258e-05 - val_coord_loss: 0.2717 - val_classes_loss: 0.6506 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6286 - val_classes_accuracy: 0.7524
# Epoch 36/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.5744 - p_loss: 5.3759e-06 - coord_loss: 0.0782 - classes_loss: 0.1835 - p_accuracy: 1.0000 - coord_IoU: 0.7160 - classes_accuracy: 0.9592 - val_loss: 2.2018 - val_p_loss: 7.1706e-05 - val_coord_loss: 0.3087 - val_classes_loss: 0.6583 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5973 - val_classes_accuracy: 0.7381
# Epoch 37/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.5296 - p_loss: 5.7116e-06 - coord_loss: 0.0721 - classes_loss: 0.1689 - p_accuracy: 1.0000 - coord_IoU: 0.7220 - classes_accuracy: 0.9687 - val_loss: 2.0042 - val_p_loss: 4.3486e-05 - val_coord_loss: 0.2750 - val_classes_loss: 0.6292 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6141 - val_classes_accuracy: 0.7619
# Epoch 38/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.4748 - p_loss: 4.5736e-06 - coord_loss: 0.0654 - classes_loss: 0.1477 - p_accuracy: 1.0000 - coord_IoU: 0.7293 - classes_accuracy: 0.9761 - val_loss: 2.0387 - val_p_loss: 1.8747e-05 - val_coord_loss: 0.2802 - val_classes_loss: 0.6378 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6244 - val_classes_accuracy: 0.7571
# Epoch 39/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.4625 - p_loss: 3.5923e-06 - coord_loss: 0.0659 - classes_loss: 0.1328 - p_accuracy: 1.0000 - coord_IoU: 0.7294 - classes_accuracy: 0.9783 - val_loss: 2.0261 - val_p_loss: 1.3703e-05 - val_coord_loss: 0.2787 - val_classes_loss: 0.6324 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6174 - val_classes_accuracy: 0.7667
# Epoch 40/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.4483 - p_loss: 2.5157e-06 - coord_loss: 0.0646 - classes_loss: 0.1253 - p_accuracy: 1.0000 - coord_IoU: 0.7325 - classes_accuracy: 0.9814 - val_loss: 2.1331 - val_p_loss: 3.3077e-05 - val_coord_loss: 0.3014 - val_classes_loss: 0.6260 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6053 - val_classes_accuracy: 0.7762
# Epoch 41/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.4327 - p_loss: 2.7168e-06 - coord_loss: 0.0634 - classes_loss: 0.1159 - p_accuracy: 1.0000 - coord_IoU: 0.7378 - classes_accuracy: 0.9783 - val_loss: 2.0500 - val_p_loss: 2.5982e-05 - val_coord_loss: 0.2837 - val_classes_loss: 0.6314 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6125 - val_classes_accuracy: 0.7429
# Epoch 42/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.4031 - p_loss: 3.1304e-06 - coord_loss: 0.0614 - classes_loss: 0.0963 - p_accuracy: 1.0000 - coord_IoU: 0.7432 - classes_accuracy: 0.9899 - val_loss: 2.0382 - val_p_loss: 2.2528e-05 - val_coord_loss: 0.2801 - val_classes_loss: 0.6378 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6265 - val_classes_accuracy: 0.7571
# Epoch 43/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.4036 - p_loss: 2.7746e-06 - coord_loss: 0.0616 - classes_loss: 0.0955 - p_accuracy: 1.0000 - coord_IoU: 0.7332 - classes_accuracy: 0.9899 - val_loss: 2.1100 - val_p_loss: 1.5739e-05 - val_coord_loss: 0.2948 - val_classes_loss: 0.6360 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5979 - val_classes_accuracy: 0.7381
# Epoch 44/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.3859 - p_loss: 2.3494e-06 - coord_loss: 0.0593 - classes_loss: 0.0893 - p_accuracy: 1.0000 - coord_IoU: 0.7437 - classes_accuracy: 0.9883 - val_loss: 2.0425 - val_p_loss: 2.1366e-05 - val_coord_loss: 0.2776 - val_classes_loss: 0.6545 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6137 - val_classes_accuracy: 0.7524
# Epoch 45/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.3428 - p_loss: 3.9944e-06 - coord_loss: 0.0543 - classes_loss: 0.0712 - p_accuracy: 1.0000 - coord_IoU: 0.7533 - classes_accuracy: 0.9926 - val_loss: 1.9741 - val_p_loss: 1.0635e-05 - val_coord_loss: 0.2705 - val_classes_loss: 0.6215 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6249 - val_classes_accuracy: 0.7857
# Epoch 46/50
# 118/118 [==============================] - 4s 33ms/step - loss: 0.3341 - p_loss: 2.4302e-06 - coord_loss: 0.0529 - classes_loss: 0.0696 - p_accuracy: 1.0000 - coord_IoU: 0.7527 - classes_accuracy: 0.9905 - val_loss: 2.0646 - val_p_loss: 1.2385e-05 - val_coord_loss: 0.2797 - val_classes_loss: 0.6661 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6117 - val_classes_accuracy: 0.7429
# Epoch 47/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.3540 - p_loss: 4.2690e-06 - coord_loss: 0.0563 - classes_loss: 0.0725 - p_accuracy: 1.0000 - coord_IoU: 0.7495 - classes_accuracy: 0.9942 - val_loss: 2.0721 - val_p_loss: 1.4127e-05 - val_coord_loss: 0.2775 - val_classes_loss: 0.6844 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6069 - val_classes_accuracy: 0.7571
# Epoch 48/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.3037 - p_loss: 2.0360e-06 - coord_loss: 0.0499 - classes_loss: 0.0544 - p_accuracy: 1.0000 - coord_IoU: 0.7615 - classes_accuracy: 0.9958 - val_loss: 1.9927 - val_p_loss: 1.4307e-05 - val_coord_loss: 0.2730 - val_classes_loss: 0.6279 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6243 - val_classes_accuracy: 0.7714
# Epoch 49/50
# 118/118 [==============================] - 4s 34ms/step - loss: 0.2839 - p_loss: 2.6062e-06 - coord_loss: 0.0465 - classes_loss: 0.0512 - p_accuracy: 1.0000 - coord_IoU: 0.7642 - classes_accuracy: 0.9984 - val_loss: 2.1555 - val_p_loss: 1.5976e-05 - val_coord_loss: 0.2966 - val_classes_loss: 0.6724 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6003 - val_classes_accuracy: 0.7619
# Epoch 50/50
# 118/118 [==============================] - 4s 32ms/step - loss: 0.2864 - p_loss: 2.1701e-06 - coord_loss: 0.0490 - classes_loss: 0.0416 - p_accuracy: 1.0000 - coord_IoU: 0.7605 - classes_accuracy: 0.9984 - val_loss: 2.1171 - val_p_loss: 1.9969e-05 - val_coord_loss: 0.2974 - val_classes_loss: 0.6299 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6109 - val_classes_accuracy: 0.7810

# %%
# Analyse des résultats : courbes d'évolution de la fonction de perte, et de l'IoU des boîtes englobantes ainsi que de la précision des classes prédites
plot_training_analysis(history, metric='loss')
plot_training_analysis(history, metric='coord_IoU')
plot_training_analysis(history, metric='classes_accuracy')

# Prédiction des données de test
y_pred_presence, y_pred_coords, y_pred_classes = model.predict(x_test)
y_pred = np.zeros(y_test.shape)
for i in range(y_pred.shape[0]):
  y_pred[i, 0] = y_pred_presence[i]
  y_pred[i, 1:5] = y_pred_coords[i]
  y_pred[i, 5:] = y_pred_classes[i]

# Affichage des résultats sur plusieurs images
print_data_localisation(x_test, y_test, y_pred = y_pred, id=1, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=2, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=3, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=4, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=5, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=6, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=7, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=8, image_size=IMAGE_SIZE)


class_res, accuracy = global_accuracy(y_test, y_pred, iou_thres=0.4)

print(f"La précision globale est de {accuracy:.1f}%")

print()
print("------------------------------------------")
print("| Classe | Précision | Rappel | F1-score |")
print("------------------------------------------")
for i in range(num_classes):
  print(f"| {class_labels[i]:7s}|   {class_res[i]['Precision']:.2f}    |  {class_res[i]['Rappel']:.2f}  |   {class_res[i]['F-score']:.2f}   |")
  print("------------------------------------------")
# Out:
# La précision globale est de 60.1%
#
# ------------------------------------------
# | Classe | Précision | Rappel | F1-score |
# ------------------------------------------
# | MESCHA |   0.19    |  0.18  |   0.19   |
# ------------------------------------------
# | VEREUR |   0.70    |  0.73  |   0.71   |
# ------------------------------------------
# | ECUROU |   0.87    |  0.91  |   0.89   |
# ------------------------------------------
# | PIEBAV |   0.91    |  0.91  |   0.91   |
# ------------------------------------------
# | SITTOR |   0.60    |  0.41  |   0.49   |
# ------------------------------------------
# | PINARB |   0.82    |  0.82  |   0.82   |
# ------------------------------------------
# | MESNOI |   0.25    |  0.36  |   0.29   |
# ------------------------------------------
# | MESNON |   0.32    |  0.32  |   0.32   |
# ------------------------------------------
# | MESBLE |   0.42    |  0.36  |   0.39   |
# ------------------------------------------
# | ROUGOR |   0.73    |  0.76  |   0.74   |
# ------------------------------------------
# | ACCMOU |   0.71    |  0.77  |   0.74   |
# ------------------------------------------

# %% [markdown]
# ## Augmentation + Transfer Learning

# %%
from tensorflow.keras.applications import VGG16

conv_base = VGG16(weights='imagenet',
                  include_top=False, # On ne conserve pas la partie Dense du réseau originel
                  input_shape=(64, 64, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step

# %%
def create_model_localisation(input_shape=(64, 64, 3)):

    input_layer = Input(shape=input_shape)
    vgg = conv_base(input_layer)
    x = Flatten()(vgg)

   # x = Dense(256, activation='relu')(x)

    output_p = Dense(1, activation='sigmoid', name='p')(x)
    output_coord = Dense(4, activation='linear', name='coord')(x)
    output_class = Dense(11, activation='softmax', name='classes')(x)

    output= [output_p, output_coord, output_class]
    model = Model(input_layer, output)

    return model

model = create_model_localisation()
conv_base.trainable = True
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  vgg16 (Functional)             (None, 2, 2, 512)    14714688    ['input_5[0][0]']
#
#  flatten_3 (Flatten)            (None, 2048)         0           ['vgg16[0][0]']
#
#  p (Dense)                      (None, 1)            2049        ['flatten_3[0][0]']
#
#  coord (Dense)                  (None, 4)            8196        ['flatten_3[0][0]']
#
#  classes (Dense)                (None, 11)           22539       ['flatten_3[0][0]']
#
# ==================================================================================================
# Total params: 14,747,472
# Trainable params: 14,747,472
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
batch_size=16
model = create_model_localisation()
opt = Adam(learning_rate=3e-4)  

loss=['binary_crossentropy', 'mse', 'categorical_crossentropy']
metrics=[ ['accuracy'], [iou()], ['accuracy']]
loss_weights = [1, 5, 1]

train_gen = MangeoireSequence(x_train, y_train, 16, augmentations=AUGMENTATIONS_TRAIN)


model.compile(loss=loss,
              optimizer=opt,
              metrics=metrics,
              loss_weights=loss_weights
              )
history = model.fit(train_gen,
              epochs=50,
              batch_size=batch_size,            
              validation_data=(x_val, [y_val[:,0], y_val[:,1:5], y_val[:,5:]]))
# Out:
# Epoch 1/50
# 118/118 [==============================] - 14s 95ms/step - loss: 7.5313 - p_loss: 0.0560 - coord_loss: 1.0144 - classes_loss: 2.4035 - p_accuracy: 1.0000 - coord_IoU: 0.3494 - classes_accuracy: 0.1071 - val_loss: 6.5318 - val_p_loss: 0.0167 - val_coord_loss: 0.8454 - val_classes_loss: 2.2879 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.3639 - val_classes_accuracy: 0.1810
# Epoch 2/50
# 118/118 [==============================] - 9s 79ms/step - loss: 5.3301 - p_loss: 0.0058 - coord_loss: 0.6714 - classes_loss: 1.9674 - p_accuracy: 1.0000 - coord_IoU: 0.4524 - classes_accuracy: 0.2747 - val_loss: 4.6081 - val_p_loss: 0.0014 - val_coord_loss: 0.5750 - val_classes_loss: 1.7316 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.4365 - val_classes_accuracy: 0.3286
# Epoch 3/50
# 118/118 [==============================] - 9s 79ms/step - loss: 4.1034 - p_loss: 0.0010 - coord_loss: 0.4895 - classes_loss: 1.6549 - p_accuracy: 1.0000 - coord_IoU: 0.5046 - classes_accuracy: 0.3791 - val_loss: 3.5190 - val_p_loss: 5.9383e-04 - val_coord_loss: 0.3975 - val_classes_loss: 1.5311 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5409 - val_classes_accuracy: 0.4048
# Epoch 4/50
# 118/118 [==============================] - 9s 79ms/step - loss: 3.3484 - p_loss: 3.6818e-04 - coord_loss: 0.3780 - classes_loss: 1.4579 - p_accuracy: 1.0000 - coord_IoU: 0.5554 - classes_accuracy: 0.4565 - val_loss: 2.9987 - val_p_loss: 2.5584e-04 - val_coord_loss: 0.3183 - val_classes_loss: 1.4070 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5563 - val_classes_accuracy: 0.5000
# Epoch 5/50
# 118/118 [==============================] - 9s 79ms/step - loss: 2.7206 - p_loss: 2.1391e-04 - coord_loss: 0.2853 - classes_loss: 1.2939 - p_accuracy: 1.0000 - coord_IoU: 0.5956 - classes_accuracy: 0.5371 - val_loss: 2.4568 - val_p_loss: 8.1732e-05 - val_coord_loss: 0.2500 - val_classes_loss: 1.2069 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6102 - val_classes_accuracy: 0.5476
# Epoch 6/50
# 118/118 [==============================] - 9s 78ms/step - loss: 2.3210 - p_loss: 1.0491e-04 - coord_loss: 0.2285 - classes_loss: 1.1783 - p_accuracy: 1.0000 - coord_IoU: 0.6261 - classes_accuracy: 0.5726 - val_loss: 2.4069 - val_p_loss: 5.5332e-05 - val_coord_loss: 0.2629 - val_classes_loss: 1.0923 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.5474 - val_classes_accuracy: 0.5857
# Epoch 7/50
# 118/118 [==============================] - 9s 80ms/step - loss: 2.0735 - p_loss: 6.3313e-05 - coord_loss: 0.2016 - classes_loss: 1.0653 - p_accuracy: 1.0000 - coord_IoU: 0.6453 - classes_accuracy: 0.6002 - val_loss: 2.2963 - val_p_loss: 4.1336e-05 - val_coord_loss: 0.2328 - val_classes_loss: 1.1321 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6479 - val_classes_accuracy: 0.5810
# Epoch 8/50
# 118/118 [==============================] - 10s 81ms/step - loss: 1.7785 - p_loss: 4.3940e-05 - coord_loss: 0.1651 - classes_loss: 0.9530 - p_accuracy: 1.0000 - coord_IoU: 0.6664 - classes_accuracy: 0.6601 - val_loss: 1.7291 - val_p_loss: 2.5606e-05 - val_coord_loss: 0.1739 - val_classes_loss: 0.8596 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6965 - val_classes_accuracy: 0.6857
# Epoch 9/50
# 118/118 [==============================] - 9s 79ms/step - loss: 1.5067 - p_loss: 1.8791e-05 - coord_loss: 0.1383 - classes_loss: 0.8153 - p_accuracy: 1.0000 - coord_IoU: 0.6798 - classes_accuracy: 0.7121 - val_loss: 1.4569 - val_p_loss: 1.3112e-05 - val_coord_loss: 0.1554 - val_classes_loss: 0.6801 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7062 - val_classes_accuracy: 0.7762
# Epoch 10/50
# 118/118 [==============================] - 9s 80ms/step - loss: 1.2906 - p_loss: 1.2126e-05 - coord_loss: 0.1149 - classes_loss: 0.7161 - p_accuracy: 1.0000 - coord_IoU: 0.7064 - classes_accuracy: 0.7391 - val_loss: 1.5154 - val_p_loss: 8.5701e-06 - val_coord_loss: 0.1576 - val_classes_loss: 0.7272 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7047 - val_classes_accuracy: 0.7381
# Epoch 11/50
# 118/118 [==============================] - 9s 80ms/step - loss: 1.1087 - p_loss: 8.6646e-06 - coord_loss: 0.1012 - classes_loss: 0.6028 - p_accuracy: 1.0000 - coord_IoU: 0.7031 - classes_accuracy: 0.7826 - val_loss: 1.4916 - val_p_loss: 1.0388e-05 - val_coord_loss: 0.1615 - val_classes_loss: 0.6839 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6973 - val_classes_accuracy: 0.7714
# Epoch 12/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.9984 - p_loss: 6.9820e-06 - coord_loss: 0.0933 - classes_loss: 0.5319 - p_accuracy: 1.0000 - coord_IoU: 0.7218 - classes_accuracy: 0.8134 - val_loss: 1.4142 - val_p_loss: 5.0564e-06 - val_coord_loss: 0.1537 - val_classes_loss: 0.6455 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6857 - val_classes_accuracy: 0.7571
# Epoch 13/50
# 118/118 [==============================] - 10s 80ms/step - loss: 0.8930 - p_loss: 4.6066e-06 - coord_loss: 0.0885 - classes_loss: 0.4507 - p_accuracy: 1.0000 - coord_IoU: 0.7245 - classes_accuracy: 0.8388 - val_loss: 1.3591 - val_p_loss: 7.3455e-06 - val_coord_loss: 0.1632 - val_classes_loss: 0.5431 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7046 - val_classes_accuracy: 0.8000
# Epoch 14/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.8402 - p_loss: 3.9269e-06 - coord_loss: 0.0851 - classes_loss: 0.4146 - p_accuracy: 1.0000 - coord_IoU: 0.7375 - classes_accuracy: 0.8574 - val_loss: 1.3635 - val_p_loss: 2.7769e-06 - val_coord_loss: 0.1540 - val_classes_loss: 0.5937 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6996 - val_classes_accuracy: 0.8000
# Epoch 15/50
# 118/118 [==============================] - 9s 79ms/step - loss: 0.6533 - p_loss: 2.4123e-06 - coord_loss: 0.0680 - classes_loss: 0.3133 - p_accuracy: 1.0000 - coord_IoU: 0.7481 - classes_accuracy: 0.8945 - val_loss: 1.2536 - val_p_loss: 2.6009e-06 - val_coord_loss: 0.1386 - val_classes_loss: 0.5604 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7267 - val_classes_accuracy: 0.7714
# Epoch 16/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.5212 - p_loss: 1.6635e-06 - coord_loss: 0.0558 - classes_loss: 0.2424 - p_accuracy: 1.0000 - coord_IoU: 0.7703 - classes_accuracy: 0.9183 - val_loss: 1.3680 - val_p_loss: 2.6751e-06 - val_coord_loss: 0.1499 - val_classes_loss: 0.6187 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7069 - val_classes_accuracy: 0.8000
# Epoch 17/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.4582 - p_loss: 1.3314e-06 - coord_loss: 0.0504 - classes_loss: 0.2060 - p_accuracy: 1.0000 - coord_IoU: 0.7858 - classes_accuracy: 0.9332 - val_loss: 1.2082 - val_p_loss: 2.1996e-06 - val_coord_loss: 0.1243 - val_classes_loss: 0.5870 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7345 - val_classes_accuracy: 0.7952
# Epoch 18/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.4977 - p_loss: 1.6819e-06 - coord_loss: 0.0579 - classes_loss: 0.2082 - p_accuracy: 1.0000 - coord_IoU: 0.7724 - classes_accuracy: 0.9316 - val_loss: 1.4121 - val_p_loss: 1.5116e-06 - val_coord_loss: 0.1550 - val_classes_loss: 0.6369 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7240 - val_classes_accuracy: 0.8048
# Epoch 19/50
# 118/118 [==============================] - 9s 79ms/step - loss: 0.3740 - p_loss: 1.0528e-06 - coord_loss: 0.0461 - classes_loss: 0.1434 - p_accuracy: 1.0000 - coord_IoU: 0.7771 - classes_accuracy: 0.9602 - val_loss: 1.2842 - val_p_loss: 1.6389e-06 - val_coord_loss: 0.1302 - val_classes_loss: 0.6331 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7279 - val_classes_accuracy: 0.8238
# Epoch 20/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.3035 - p_loss: 8.1768e-07 - coord_loss: 0.0391 - classes_loss: 0.1081 - p_accuracy: 1.0000 - coord_IoU: 0.7940 - classes_accuracy: 0.9682 - val_loss: 1.2060 - val_p_loss: 8.5393e-07 - val_coord_loss: 0.1258 - val_classes_loss: 0.5768 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7383 - val_classes_accuracy: 0.8190
# Epoch 21/50
# 118/118 [==============================] - 9s 79ms/step - loss: 0.2867 - p_loss: 7.3844e-07 - coord_loss: 0.0386 - classes_loss: 0.0934 - p_accuracy: 1.0000 - coord_IoU: 0.7953 - classes_accuracy: 0.9761 - val_loss: 1.1262 - val_p_loss: 8.3519e-07 - val_coord_loss: 0.1194 - val_classes_loss: 0.5293 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7410 - val_classes_accuracy: 0.8524
# Epoch 22/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.3145 - p_loss: 7.6383e-07 - coord_loss: 0.0398 - classes_loss: 0.1153 - p_accuracy: 1.0000 - coord_IoU: 0.7946 - classes_accuracy: 0.9655 - val_loss: 1.1051 - val_p_loss: 8.5571e-07 - val_coord_loss: 0.1163 - val_classes_loss: 0.5235 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7429 - val_classes_accuracy: 0.8667
# Epoch 23/50
# 118/118 [==============================] - 9s 79ms/step - loss: 0.2883 - p_loss: 9.0311e-07 - coord_loss: 0.0365 - classes_loss: 0.1057 - p_accuracy: 1.0000 - coord_IoU: 0.7979 - classes_accuracy: 0.9692 - val_loss: 1.2949 - val_p_loss: 1.4352e-06 - val_coord_loss: 0.1357 - val_classes_loss: 0.6162 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7390 - val_classes_accuracy: 0.8238
# Epoch 24/50
# 118/118 [==============================] - 10s 83ms/step - loss: 0.2496 - p_loss: 6.9637e-07 - coord_loss: 0.0345 - classes_loss: 0.0769 - p_accuracy: 1.0000 - coord_IoU: 0.8083 - classes_accuracy: 0.9756 - val_loss: 1.1960 - val_p_loss: 1.0909e-06 - val_coord_loss: 0.1183 - val_classes_loss: 0.6048 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7255 - val_classes_accuracy: 0.8429
# Epoch 25/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.2675 - p_loss: 8.7989e-07 - coord_loss: 0.0382 - classes_loss: 0.0766 - p_accuracy: 1.0000 - coord_IoU: 0.7991 - classes_accuracy: 0.9809 - val_loss: 1.2100 - val_p_loss: 8.6829e-07 - val_coord_loss: 0.1260 - val_classes_loss: 0.5798 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6988 - val_classes_accuracy: 0.8333
# Epoch 26/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.2472 - p_loss: 9.4940e-07 - coord_loss: 0.0353 - classes_loss: 0.0706 - p_accuracy: 1.0000 - coord_IoU: 0.7970 - classes_accuracy: 0.9777 - val_loss: 1.1687 - val_p_loss: 1.6536e-06 - val_coord_loss: 0.1244 - val_classes_loss: 0.5466 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7462 - val_classes_accuracy: 0.8619
# Epoch 27/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.1861 - p_loss: 8.0705e-07 - coord_loss: 0.0286 - classes_loss: 0.0431 - p_accuracy: 1.0000 - coord_IoU: 0.8176 - classes_accuracy: 0.9883 - val_loss: 1.1594 - val_p_loss: 1.2007e-06 - val_coord_loss: 0.1208 - val_classes_loss: 0.5552 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7491 - val_classes_accuracy: 0.8381
# Epoch 28/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.1416 - p_loss: 6.7068e-07 - coord_loss: 0.0226 - classes_loss: 0.0287 - p_accuracy: 1.0000 - coord_IoU: 0.8431 - classes_accuracy: 0.9947 - val_loss: 1.2111 - val_p_loss: 6.0202e-07 - val_coord_loss: 0.1068 - val_classes_loss: 0.6772 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7671 - val_classes_accuracy: 0.8381
# Epoch 29/50
# 118/118 [==============================] - 9s 79ms/step - loss: 0.2272 - p_loss: 8.2937e-07 - coord_loss: 0.0294 - classes_loss: 0.0801 - p_accuracy: 1.0000 - coord_IoU: 0.8145 - classes_accuracy: 0.9740 - val_loss: 1.1493 - val_p_loss: 1.3927e-06 - val_coord_loss: 0.1225 - val_classes_loss: 0.5366 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7467 - val_classes_accuracy: 0.8381
# Epoch 30/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.1430 - p_loss: 6.4247e-07 - coord_loss: 0.0236 - classes_loss: 0.0252 - p_accuracy: 1.0000 - coord_IoU: 0.8294 - classes_accuracy: 0.9947 - val_loss: 1.1389 - val_p_loss: 6.4515e-07 - val_coord_loss: 0.1148 - val_classes_loss: 0.5648 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7550 - val_classes_accuracy: 0.8619
# Epoch 31/50
# 118/118 [==============================] - 10s 82ms/step - loss: 0.0943 - p_loss: 6.0319e-07 - coord_loss: 0.0162 - classes_loss: 0.0133 - p_accuracy: 1.0000 - coord_IoU: 0.8570 - classes_accuracy: 0.9984 - val_loss: 1.0475 - val_p_loss: 6.3735e-07 - val_coord_loss: 0.1069 - val_classes_loss: 0.5131 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7782 - val_classes_accuracy: 0.8476
# Epoch 32/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.0793 - p_loss: 4.3925e-07 - coord_loss: 0.0143 - classes_loss: 0.0080 - p_accuracy: 1.0000 - coord_IoU: 0.8614 - classes_accuracy: 0.9995 - val_loss: 1.0425 - val_p_loss: 7.7888e-07 - val_coord_loss: 0.1056 - val_classes_loss: 0.5143 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7637 - val_classes_accuracy: 0.8476
# Epoch 33/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.0557 - p_loss: 4.1602e-07 - coord_loss: 0.0102 - classes_loss: 0.0047 - p_accuracy: 1.0000 - coord_IoU: 0.8852 - classes_accuracy: 1.0000 - val_loss: 1.1050 - val_p_loss: 4.6194e-07 - val_coord_loss: 0.1117 - val_classes_loss: 0.5465 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7613 - val_classes_accuracy: 0.8571
# Epoch 34/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.0452 - p_loss: 3.6769e-07 - coord_loss: 0.0083 - classes_loss: 0.0039 - p_accuracy: 1.0000 - coord_IoU: 0.8944 - classes_accuracy: 1.0000 - val_loss: 1.0788 - val_p_loss: 4.1695e-07 - val_coord_loss: 0.1060 - val_classes_loss: 0.5490 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7703 - val_classes_accuracy: 0.8524
# Epoch 35/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.0569 - p_loss: 3.2166e-07 - coord_loss: 0.0105 - classes_loss: 0.0046 - p_accuracy: 1.0000 - coord_IoU: 0.8884 - classes_accuracy: 1.0000 - val_loss: 1.1381 - val_p_loss: 4.0025e-07 - val_coord_loss: 0.1113 - val_classes_loss: 0.5815 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7594 - val_classes_accuracy: 0.8571
# Epoch 36/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.0728 - p_loss: 3.5588e-07 - coord_loss: 0.0128 - classes_loss: 0.0089 - p_accuracy: 1.0000 - coord_IoU: 0.8804 - classes_accuracy: 0.9984 - val_loss: 1.1650 - val_p_loss: 5.9484e-07 - val_coord_loss: 0.1116 - val_classes_loss: 0.6071 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7523 - val_classes_accuracy: 0.8286
# Epoch 37/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.0731 - p_loss: 4.1488e-07 - coord_loss: 0.0127 - classes_loss: 0.0095 - p_accuracy: 1.0000 - coord_IoU: 0.8722 - classes_accuracy: 0.9989 - val_loss: 1.0694 - val_p_loss: 7.5584e-07 - val_coord_loss: 0.1020 - val_classes_loss: 0.5593 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7694 - val_classes_accuracy: 0.8524
# Epoch 38/50
# 118/118 [==============================] - 10s 81ms/step - loss: 0.4307 - p_loss: 1.1899e-06 - coord_loss: 0.0530 - classes_loss: 0.1657 - p_accuracy: 1.0000 - coord_IoU: 0.7889 - classes_accuracy: 0.9475 - val_loss: 2.4380 - val_p_loss: 5.0249e-06 - val_coord_loss: 0.2001 - val_classes_loss: 1.4377 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.6451 - val_classes_accuracy: 0.6619
# Epoch 39/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.8355 - p_loss: 9.1652e-06 - coord_loss: 0.1061 - classes_loss: 0.3052 - p_accuracy: 1.0000 - coord_IoU: 0.7111 - classes_accuracy: 0.8993 - val_loss: 1.6247 - val_p_loss: 4.0363e-06 - val_coord_loss: 0.1592 - val_classes_loss: 0.8286 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7133 - val_classes_accuracy: 0.7667
# Epoch 40/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.4155 - p_loss: 2.7989e-06 - coord_loss: 0.0520 - classes_loss: 0.1557 - p_accuracy: 1.0000 - coord_IoU: 0.7734 - classes_accuracy: 0.9523 - val_loss: 1.3908 - val_p_loss: 3.4772e-06 - val_coord_loss: 0.1541 - val_classes_loss: 0.6203 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7002 - val_classes_accuracy: 0.8381
# Epoch 41/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.2004 - p_loss: 1.5955e-06 - coord_loss: 0.0308 - classes_loss: 0.0465 - p_accuracy: 1.0000 - coord_IoU: 0.8198 - classes_accuracy: 0.9899 - val_loss: 1.2611 - val_p_loss: 1.0400e-06 - val_coord_loss: 0.1152 - val_classes_loss: 0.6851 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7496 - val_classes_accuracy: 0.7905
# Epoch 42/50
# 118/118 [==============================] - 10s 81ms/step - loss: 0.1760 - p_loss: 6.7098e-07 - coord_loss: 0.0250 - classes_loss: 0.0510 - p_accuracy: 1.0000 - coord_IoU: 0.8350 - classes_accuracy: 0.9873 - val_loss: 1.2340 - val_p_loss: 8.4517e-07 - val_coord_loss: 0.1227 - val_classes_loss: 0.6207 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7522 - val_classes_accuracy: 0.8571
# Epoch 43/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.0987 - p_loss: 6.0104e-07 - coord_loss: 0.0174 - classes_loss: 0.0115 - p_accuracy: 1.0000 - coord_IoU: 0.8591 - classes_accuracy: 0.9989 - val_loss: 1.1462 - val_p_loss: 5.4753e-07 - val_coord_loss: 0.1116 - val_classes_loss: 0.5882 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7700 - val_classes_accuracy: 0.8571
# Epoch 44/50
# 118/118 [==============================] - 10s 80ms/step - loss: 0.0914 - p_loss: 4.7931e-07 - coord_loss: 0.0140 - classes_loss: 0.0216 - p_accuracy: 1.0000 - coord_IoU: 0.8692 - classes_accuracy: 0.9936 - val_loss: 1.1406 - val_p_loss: 7.0616e-07 - val_coord_loss: 0.1113 - val_classes_loss: 0.5841 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7369 - val_classes_accuracy: 0.8381
# Epoch 45/50
# 118/118 [==============================] - 10s 83ms/step - loss: 0.1956 - p_loss: 6.5749e-07 - coord_loss: 0.0228 - classes_loss: 0.0817 - p_accuracy: 1.0000 - coord_IoU: 0.8338 - classes_accuracy: 0.9745 - val_loss: 1.4827 - val_p_loss: 1.1105e-06 - val_coord_loss: 0.1287 - val_classes_loss: 0.8393 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7514 - val_classes_accuracy: 0.7952
# Epoch 46/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.2489 - p_loss: 1.0259e-06 - coord_loss: 0.0364 - classes_loss: 0.0670 - p_accuracy: 1.0000 - coord_IoU: 0.8134 - classes_accuracy: 0.9809 - val_loss: 1.2706 - val_p_loss: 8.9042e-07 - val_coord_loss: 0.1367 - val_classes_loss: 0.5871 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7427 - val_classes_accuracy: 0.8429
# Epoch 47/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.2193 - p_loss: 9.8730e-07 - coord_loss: 0.0334 - classes_loss: 0.0524 - p_accuracy: 1.0000 - coord_IoU: 0.8212 - classes_accuracy: 0.9867 - val_loss: 1.3455 - val_p_loss: 1.9522e-06 - val_coord_loss: 0.1431 - val_classes_loss: 0.6299 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7144 - val_classes_accuracy: 0.8381
# Epoch 48/50
# 118/118 [==============================] - 10s 83ms/step - loss: 0.1980 - p_loss: 7.6856e-07 - coord_loss: 0.0295 - classes_loss: 0.0505 - p_accuracy: 1.0000 - coord_IoU: 0.8196 - classes_accuracy: 0.9846 - val_loss: 1.3081 - val_p_loss: 8.2150e-07 - val_coord_loss: 0.1251 - val_classes_loss: 0.6828 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7632 - val_classes_accuracy: 0.8143
# Epoch 49/50
# 118/118 [==============================] - 10s 81ms/step - loss: 0.0984 - p_loss: 6.1311e-07 - coord_loss: 0.0169 - classes_loss: 0.0137 - p_accuracy: 1.0000 - coord_IoU: 0.8611 - classes_accuracy: 0.9973 - val_loss: 1.1559 - val_p_loss: 6.9643e-07 - val_coord_loss: 0.1154 - val_classes_loss: 0.5789 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7658 - val_classes_accuracy: 0.8571
# Epoch 50/50
# 118/118 [==============================] - 10s 81ms/step - loss: 0.0609 - p_loss: 3.8026e-07 - coord_loss: 0.0113 - classes_loss: 0.0044 - p_accuracy: 1.0000 - coord_IoU: 0.8856 - classes_accuracy: 1.0000 - val_loss: 1.1181 - val_p_loss: 4.2745e-07 - val_coord_loss: 0.1059 - val_classes_loss: 0.5888 - val_p_accuracy: 1.0000 - val_coord_IoU: 0.7766 - val_classes_accuracy: 0.8476

# %%
# Analyse des résultats : courbes d'évolution de la fonction de perte, et de l'IoU des boîtes englobantes ainsi que de la précision des classes prédites
plot_training_analysis(history, metric='loss')
plot_training_analysis(history, metric='coord_IoU')
plot_training_analysis(history, metric='classes_accuracy')

# Prédiction des données de test
y_pred_presence, y_pred_coords, y_pred_classes = model.predict(x_test)
y_pred = np.zeros(y_test.shape)
for i in range(y_pred.shape[0]):
  y_pred[i, 0] = y_pred_presence[i]
  y_pred[i, 1:5] = y_pred_coords[i]
  y_pred[i, 5:] = y_pred_classes[i]

# Affichage des résultats sur plusieurs images
print_data_localisation(x_test, y_test, y_pred = y_pred, id=1, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=2, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=3, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=4, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=5, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=6, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=7, image_size=IMAGE_SIZE)
print_data_localisation(x_test, y_test, y_pred = y_pred, id=8, image_size=IMAGE_SIZE)


class_res, accuracy = global_accuracy(y_test, y_pred, iou_thres=0.4)

print(f"La précision globale est de {accuracy:.1f}%")

print()
print("------------------------------------------")
print("| Classe | Précision | Rappel | F1-score |")
print("------------------------------------------")
for i in range(num_classes):
  print(f"| {class_labels[i]:7s}|   {class_res[i]['Precision']:.2f}    |  {class_res[i]['Rappel']:.2f}  |   {class_res[i]['F-score']:.2f}   |")
  print("------------------------------------------")
# Out:
# La précision globale est de 77.7%
#
# ------------------------------------------
# | Classe | Précision | Rappel | F1-score |
# ------------------------------------------
# | MESCHA |   0.50    |  0.45  |   0.48   |
# ------------------------------------------
# | VEREUR |   0.86    |  0.82  |   0.84   |
# ------------------------------------------
# | ECUROU |   0.95    |  0.91  |   0.93   |
# ------------------------------------------
# | PIEBAV |   1.00    |  0.95  |   0.98   |
# ------------------------------------------
# | SITTOR |   0.80    |  0.73  |   0.76   |
# ------------------------------------------
# | PINARB |   0.91    |  0.91  |   0.91   |
# ------------------------------------------
# | MESNOI |   0.73    |  0.57  |   0.64   |
# ------------------------------------------
# | MESNON |   0.55    |  0.73  |   0.63   |
# ------------------------------------------
# | MESBLE |   0.62    |  0.68  |   0.65   |
# ------------------------------------------
# | ROUGOR |   0.85    |  0.81  |   0.83   |
# ------------------------------------------
# | ACCMOU |   0.83    |  0.91  |   0.87   |
# ------------------------------------------
